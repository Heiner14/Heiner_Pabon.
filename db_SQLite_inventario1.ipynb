# %% [markdown]
# <a href="https://colab.research.google.com/github/Heiner14/Heiner_Pabon./blob/main/db_SQLite_inventario1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gestión Básica de Inventario con SQLite3
#
# **Autor: Elias Buitrago B.**\
# Bogotá, Colombia \
# Actualizado: 22 abril 202a \
# _Nota: Código ajustado para su ejecución en Google Colaboratory_\

# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   sqlite3
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 769 kB of archives.
# After this operation, 1,874 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sqlite3 amd64 3.37.2-2ubuntu0.5 [769 kB]
# Fetched 769 kB in 0s (2,817 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package sqlite3.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../sqlite3_3.37.2-2ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.37.2-2ubuntu0.5) ...
# Setting up sqlite3 (3.37.2-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-3996919643.py in <cell line: 0>()
#       1 # Crear una tabla llamada 'inventario'
# ----> 2 c.execute('''
#       3 CREATE TABLE inventario (
#       4     id INTEGER PRIMARY KEY AUTOINCREMENT,
#       5     nombre TEXT,
#
# OperationalError: table inventario already exists

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Artículo1', 'Jardín', 332.28, 32, 'Proveedor1', '2023-12-03', 'Almacén A')
# (2, 'Objeto2', 'Jardín', 147.26, 85, 'Proveedor1', '2023-10-07', 'Almacén C')
# (3, 'Objeto3', 'Deportes', 109.86, 30, 'Proveedor3', '2023-11-09', 'Almacén C')
# (4, 'Producto4', 'Electrónica', 330.51, 30, 'Proveedor1', '2023-06-26', 'Almacén A')
# (5, 'Objeto5', 'Jardín', 456.25, 34, 'Proveedor1', '2023-05-20', 'Almacén C')
# (6, 'Objeto6', 'Electrónica', 96.53, 23, 'Proveedor3', '2023-09-10', 'Almacén A')
# (7, 'Objeto7', 'Electrónica', 365.4, 6, 'Proveedor1', '2023-08-18', 'Almacén C')
# (8, 'Objeto8', 'Electrónica', 206.03, 31, 'Proveedor2', '2023-12-24', 'Almacén B')
# (9, 'Artículo9', 'Jardín', 292.97, 11, 'Proveedor3', '2023-09-13', 'Almacén B')
# (10, 'Objeto10', 'Electrónica', 397.85, 58, 'Proveedor3', '2023-08-17', 'Almacén B')
# (11, 'Objeto11', 'Electrónica', 145.45, 34, 'Proveedor2', '2023-07-12', 'Almacén C')
# (12, 'Objeto12', 'Jardín', 220.55, 29, 'Proveedor1', '2023-12-25', 'Almacén C')
# (13, 'Artículo13', 'Electrónica', 278.66, 40, 'Proveedor3', '2023-01-03', 'Almacén B')
# (14, 'Producto14', 'Electrónica', 357.65, 72, 'Proveedor1', '2023-02-13', 'Almacén C')
# (15, 'Producto15', 'Deportes', 319.78, 9, 'Proveedor3', '2023-10-12', 'Almacén B')
# (16, 'Producto16', 'Deportes', 167.92, 70, 'Proveedor1', '2023-10-16', 'Almacén A')
# (17, 'Producto17', 'Electrónica', 16.6, 44, 'Proveedor1', '2023-10-23', 'Almacén C')
# (18, 'Artículo18', 'Electrónica', 70.56, 56, 'Proveedor2', '2023-03-09', 'Almacén A')
# (19, 'Artículo19', 'Hogar', 413.37, 22, 'Proveedor3', '2023-12-07', 'Almacén B')
# (20, 'Objeto20', 'Moda', 304.14, 76, 'Proveedor1', '2023-07-07', 'Almacén C')
# (21, 'Artículo21', 'Moda', 263.59, 87, 'Proveedor3', '2023-12-25', 'Almacén B')
# (22, 'Producto22', 'Electrónica', 95.7, 53, 'Proveedor1', '2023-12-22', 'Almacén C')
# (23, 'Objeto23', 'Jardín', 295.05, 53, 'Proveedor3', '2023-05-20', 'Almacén B')
# (24, 'Producto24', 'Hogar', 456.64, 61, 'Proveedor1', '2023-07-12', 'Almacén B')
# (25, 'Artículo25', 'Moda', 164, 37, 'Proveedor3', '2023-05-13', 'Almacén B')
# (26, 'Artículo26', 'Jardín', 65.48, 11, 'Proveedor1', '2023-03-21', 'Almacén B')
# (27, 'Objeto27', 'Electrónica', 127.05, 3, 'Proveedor2', '2023-02-03', 'Almacén B')
# (28, 'Producto28', 'Hogar', 122.46, 95, 'Proveedor1', '2023-07-21', 'Almacén A')
# (29, 'Objeto29', 'Deportes', 177.94, 11, 'Proveedor3', '2023-01-19', 'Almacén A')
# (30, 'Objeto30', 'Moda', 59.88, 27, 'Proveedor1', '2023-01-16', 'Almacén B')
# (31, 'Objeto31', 'Moda', 379.12, 28, 'Proveedor1', '2023-02-18', 'Almacén B')
# (32, 'Artículo32', 'Deportes', 196.61, 11, 'Proveedor1', '2023-02-22', 'Almacén B')
# (33, 'Producto33', 'Jardín', 221.71, 80, 'Proveedor3', '2023-12-22', 'Almacén A')
# (34, 'Objeto34', 'Jardín', 221.84, 21, 'Proveedor3', '2023-03-12', 'Almacén B')
# (35, 'Objeto35', 'Moda', 262.3, 64, 'Proveedor2', '2023-12-01', 'Almacén B')
# (36, 'Artículo36', 'Deportes', 192.72, 23, 'Proveedor1', '2023-10-20', 'Almacén C')
# (37, 'Producto37', 'Moda', 414.99, 46, 'Proveedor2', '2023-11-12', 'Almacén A')
# (38, 'Objeto38', 'Jardín', 174.81, 96, 'Proveedor3', '2023-04-02', 'Almacén C')
# (39, 'Artículo39', 'Deportes', 194.15, 17, 'Proveedor1', '2023-04-09', 'Almacén A')
# (40, 'Objeto40', 'Deportes', 149.32, 44, 'Proveedor2', '2023-09-23', 'Almacén B')
# (41, 'Objeto41', 'Electrónica', 246.32, 10, 'Proveedor2', '2023-04-24', 'Almacén B')
# (42, 'Producto42', 'Electrónica', 350.93, 89, 'Proveedor2', '2023-03-22', 'Almacén C')
# (43, 'Objeto43', 'Deportes', 129.27, 38, 'Proveedor1', '2023-11-16', 'Almacén B')
# (44, 'Artículo44', 'Electrónica', 226.76, 85, 'Proveedor1', '2023-08-12', 'Almacén B')
# (45, 'Artículo45', 'Electrónica', 422.64, 86, 'Proveedor3', '2023-07-02', 'Almacén C')
# (46, 'Producto46', 'Hogar', 437.44, 13, 'Proveedor1', '2023-06-24', 'Almacén C')
# (47, 'Producto47', 'Jardín', 382.03, 67, 'Proveedor2', '2023-09-05', 'Almacén B')
# (48, 'Artículo48', 'Electrónica', 196.2, 88, 'Proveedor1', '2023-11-24', 'Almacén A')
# (49, 'Producto49', 'Jardín', 117.28, 42, 'Proveedor2', '2023-04-06', 'Almacén A')
# (50, 'Artículo50', 'Hogar', 343.91, 57, 'Proveedor3', '2023-08-18', 'Almacén A')
# (51, 'Artículo51', 'Hogar', 41.58, 11, 'Proveedor2', '2023-05-06', 'Almacén B')
# (52, 'Objeto52', 'Hogar', 96.43, 63, 'Proveedor2', '2023-12-24', 'Almacén C')
# (53, 'Artículo53', 'Jardín', 381.71, 7, 'Proveedor1', '2023-12-26', 'Almacén A')
# (54, 'Artículo54', 'Jardín', 471.35, 18, 'Proveedor1', '2023-03-11', 'Almacén B')
# (55, 'Objeto55', 'Moda', 40.54, 74, 'Proveedor2', '2023-04-26', 'Almacén C')
# (56, 'Objeto56', 'Jardín', 485.91, 18, 'Proveedor1', '2023-08-07', 'Almacén B')
# (57, 'Artículo57', 'Deportes', 218.35, 38, 'Proveedor2', '2023-02-11', 'Almacén B')
# (58, 'Producto58', 'Moda', 151.68, 92, 'Proveedor3', '2023-01-12', 'Almacén C')
# (59, 'Producto59', 'Jardín', 420.26, 89, 'Proveedor1', '2023-09-21', 'Almacén C')
# (60, 'Producto60', 'Hogar', 188.11, 78, 'Proveedor2', '2023-07-25', 'Almacén B')
# (61, 'Objeto61', 'Electrónica', 358.53, 40, 'Proveedor2', '2023-03-14', 'Almacén B')
# (62, 'Producto62', 'Jardín', 413.9, 4, 'Proveedor1', '2023-01-15', 'Almacén B')
# (63, 'Producto63', 'Hogar', 440.89, 30, 'Proveedor1', '2023-03-07', 'Almacén B')
# (64, 'Producto64', 'Jardín', 40.68, 100, 'Proveedor2', '2023-11-25', 'Almacén A')
# (65, 'Artículo65', 'Electrónica', 264.6, 62, 'Proveedor3', '2023-09-09', 'Almacén A')
# (66, 'Artículo66', 'Jardín', 112.83, 15, 'Proveedor3', '2023-08-27', 'Almacén A')
# (67, 'Producto67', 'Deportes', 405.02, 38, 'Proveedor1', '2023-06-10', 'Almacén C')
# (68, 'Objeto68', 'Hogar', 320.02, 25, 'Proveedor2', '2023-08-22', 'Almacén C')
# (69, 'Producto69', 'Jardín', 431.13, 31, 'Proveedor2', '2023-08-04', 'Almacén C')
# (70, 'Producto70', 'Jardín', 365.09, 48, 'Proveedor1', '2023-08-15', 'Almacén A')
# (71, 'Producto71', 'Hogar', 355.5, 38, 'Proveedor3', '2023-08-28', 'Almacén A')
# (72, 'Artículo72', 'Moda', 397.48, 69, 'Proveedor1', '2023-09-05', 'Almacén A')
# (73, 'Producto73', 'Jardín', 122.31, 76, 'Proveedor2', '2023-03-08', 'Almacén B')
# (74, 'Objeto74', 'Electrónica', 367.78, 21, 'Proveedor3', '2023-10-22', 'Almacén B')
# (75, 'Producto75', 'Deportes', 411.92, 24, 'Proveedor2', '2023-06-16', 'Almacén B')
# (76, 'Objeto76', 'Moda', 404.31, 14, 'Proveedor2', '2023-04-05', 'Almacén C')
# (77, 'Producto77', 'Moda', 428.27, 92, 'Proveedor2', '2023-02-27', 'Almacén B')
# (78, 'Producto78', 'Moda', 230.49, 77, 'Proveedor2', '2023-10-07', 'Almacén A')
# (79, 'Objeto79', 'Electrónica', 136.93, 33, 'Proveedor1', '2023-10-08', 'Almacén A')
# (80, 'Producto80', 'Jardín', 277.31, 8, 'Proveedor1', '2023-12-28', 'Almacén B')
# (81, 'Artículo81', 'Moda', 333.59, 86, 'Proveedor1', '2023-06-27', 'Almacén C')
# (82, 'Artículo82', 'Deportes', 443.9, 50, 'Proveedor2', '2023-02-11', 'Almacén A')
# (83, 'Objeto83', 'Hogar', 362.98, 25, 'Proveedor2', '2023-04-19', 'Almacén C')
# (84, 'Producto84', 'Deportes', 207.96, 49, 'Proveedor1', '2023-02-01', 'Almacén B')
# (85, 'Producto85', 'Jardín', 78.18, 53, 'Proveedor2', '2023-09-24', 'Almacén A')
# (86, 'Objeto86', 'Moda', 67.22, 68, 'Proveedor2', '2023-07-27', 'Almacén A')
# (87, 'Artículo87', 'Deportes', 413.85, 67, 'Proveedor2', '2023-03-09', 'Almacén A')
# (88, 'Objeto88', 'Electrónica', 406.88, 38, 'Proveedor1', '2023-01-12', 'Almacén C')
# (89, 'Objeto89', 'Jardín', 316.3, 85, 'Proveedor3', '2023-06-02', 'Almacén B')
# (90, 'Artículo90', 'Deportes', 381.64, 79, 'Proveedor1', '2023-08-26', 'Almacén B')
# (91, 'Artículo91', 'Moda', 335.46, 31, 'Proveedor2', '2023-05-02', 'Almacén C')
# (92, 'Producto92', 'Electrónica', 153.29, 79, 'Proveedor1', '2023-05-27', 'Almacén A')
# (93, 'Producto93', 'Jardín', 222.14, 44, 'Proveedor1', '2023-05-03', 'Almacén A')
# (94, 'Artículo94', 'Deportes', 66.9, 54, 'Proveedor2', '2023-12-22', 'Almacén B')
# (95, 'Producto95', 'Hogar', 446.28, 94, 'Proveedor2', '2023-12-18', 'Almacén C')
# (96, 'Producto96', 'Electrónica', 448.82, 7, 'Proveedor1', '2023-08-01', 'Almacén A')
# (97, 'Artículo97', 'Deportes', 371.61, 6, 'Proveedor1', '2023-12-06', 'Almacén B')
# (98, 'Producto98', 'Jardín', 36.82, 98, 'Proveedor3', '2023-12-23', 'Almacén A')
# (99, 'Artículo99', 'Electrónica', 188.5, 92, 'Proveedor1', '2023-02-13', 'Almacén C')
# (100, 'Artículo100', 'Jardín', 84.5, 93, 'Proveedor2', '2023-11-09', 'Almacén C')
# (101, 'Objeto101', 'Electrónica', 239.4, 11, 'Proveedor3', '2023-09-28', 'Almacén C')
# (102, 'Artículo102', 'Electrónica', 338.88, 44, 'Proveedor3', '2023-06-03', 'Almacén A')
# (103, 'Producto103', 'Electrónica', 430.36, 24, 'Proveedor2', '2023-05-10', 'Almacén C')
# (104, 'Artículo104', 'Jardín', 436.84, 30, 'Proveedor3', '2023-07-23', 'Almacén B')
# (105, 'Artículo105', 'Electrónica', 244.87, 49, 'Proveedor1', '2023-09-04', 'Almacén A')
# (106, 'Artículo106', 'Jardín', 160.92, 97, 'Proveedor2', '2023-04-26', 'Almacén B')
# (107, 'Artículo107', 'Jardín', 376.72, 83, 'Proveedor1', '2023-10-14', 'Almacén C')
# (108, 'Objeto108', 'Electrónica', 177.56, 24, 'Proveedor1', '2023-06-26', 'Almacén A')
# (109, 'Objeto109', 'Jardín', 203.07, 38, 'Proveedor3', '2023-07-13', 'Almacén C')
# (110, 'Artículo110', 'Deportes', 306.97, 14, 'Proveedor3', '2023-05-16', 'Almacén A')
# (111, 'Objeto111', 'Electrónica', 446.45, 78, 'Proveedor1', '2023-09-09', 'Almacén C')
# (112, 'Objeto112', 'Electrónica', 288.19, 94, 'Proveedor2', '2023-02-11', 'Almacén B')
# (113, 'Artículo113', 'Jardín', 318, 36, 'Proveedor1', '2023-06-27', 'Almacén B')
# (114, 'Producto114', 'Jardín', 120.59, 78, 'Proveedor2', '2023-05-19', 'Almacén C')
# (115, 'Producto115', 'Electrónica', 94.7, 46, 'Proveedor3', '2023-04-19', 'Almacén A')
# (116, 'Artículo116', 'Jardín', 410.51, 32, 'Proveedor2', '2023-03-28', 'Almacén A')
# (117, 'Objeto117', 'Electrónica', 42.9, 46, 'Proveedor1', '2023-12-01', 'Almacén A')
# (118, 'Producto118', 'Electrónica', 361.69, 68, 'Proveedor1', '2023-05-18', 'Almacén C')
# (119, 'Objeto119', 'Deportes', 256.48, 36, 'Proveedor2', '2023-11-08', 'Almacén A')
# (120, 'Artículo120', 'Hogar', 104.42, 66, 'Proveedor3', '2023-09-09', 'Almacén C')
# (121, 'Producto121', 'Jardín', 54.62, 63, 'Proveedor1', '2023-07-25', 'Almacén C')
# (122, 'Artículo122', 'Jardín', 366.35, 65, 'Proveedor2', '2023-10-27', 'Almacén B')
# (123, 'Producto123', 'Moda', 244.36, 5, 'Proveedor3', '2023-10-27', 'Almacén B')
# (124, 'Objeto124', 'Electrónica', 326.28, 95, 'Proveedor3', '2023-01-19', 'Almacén A')
# (125, 'Objeto125', 'Hogar', 425.99, 28, 'Proveedor1', '2023-05-04', 'Almacén B')
# (126, 'Objeto126', 'Hogar', 243.24, 36, 'Proveedor2', '2023-10-19', 'Almacén B')
# (127, 'Artículo127', 'Jardín', 346.79, 63, 'Proveedor1', '2023-10-14', 'Almacén C')
# (128, 'Objeto128', 'Hogar', 73.88, 47, 'Proveedor3', '2023-04-03', 'Almacén C')
# (129, 'Objeto129', 'Electrónica', 151.81, 85, 'Proveedor3', '2023-05-09', 'Almacén B')
# (130, 'Producto130', 'Electrónica', 46.7, 38, 'Proveedor2', '2023-02-14', 'Almacén A')
# (131, 'Artículo131', 'Jardín', 224.13, 47, 'Proveedor2', '2023-01-05', 'Almacén B')
# (132, 'Producto132', 'Jardín', 477.46, 72, 'Proveedor3', '2023-01-21', 'Almacén A')
# (133, 'Artículo133', 'Deportes', 17.19, 80, 'Proveedor2', '2023-09-01', 'Almacén A')
# (134, 'Producto134', 'Moda', 262.53, 27, 'Proveedor2', '2023-03-24', 'Almacén A')
# (135, 'Producto135', 'Hogar', 446.26, 85, 'Proveedor1', '2023-06-12', 'Almacén C')
# (136, 'Artículo136', 'Deportes', 243.37, 73, 'Proveedor1', '2023-11-15', 'Almacén B')
# (137, 'Producto137', 'Moda', 259.25, 53, 'Proveedor1', '2023-02-21', 'Almacén B')
# (138, 'Objeto138', 'Moda', 257.24, 42, 'Proveedor3', '2023-06-14', 'Almacén C')
# (139, 'Artículo139', 'Jardín', 263.88, 63, 'Proveedor3', '2023-02-12', 'Almacén A')
# (140, 'Artículo140', 'Electrónica', 312.98, 5, 'Proveedor2', '2023-09-25', 'Almacén A')
# (141, 'Producto141', 'Electrónica', 281.16, 34, 'Proveedor3', '2023-12-08', 'Almacén B')
# (142, 'Artículo142', 'Deportes', 147.59, 77, 'Proveedor1', '2023-10-12', 'Almacén C')
# (143, 'Objeto143', 'Moda', 35.7, 15, 'Proveedor3', '2023-05-07', 'Almacén C')
# (144, 'Artículo144', 'Hogar', 76.69, 10, 'Proveedor1', '2023-02-12', 'Almacén C')
# (145, 'Artículo145', 'Deportes', 132.34, 80, 'Proveedor1', '2023-10-17', 'Almacén B')
# (146, 'Producto146', 'Hogar', 311.57, 97, 'Proveedor3', '2023-04-22', 'Almacén C')
# (147, 'Producto147', 'Moda', 480.96, 91, 'Proveedor2', '2023-03-12', 'Almacén C')
# (148, 'Artículo148', 'Jardín', 267.08, 70, 'Proveedor3', '2023-08-21', 'Almacén B')
# (149, 'Objeto149', 'Moda', 196.34, 14, 'Proveedor1', '2023-03-24', 'Almacén A')
# (150, 'Producto150', 'Jardín', 54.68, 100, 'Proveedor1', '2023-09-27', 'Almacén A')
# (151, 'Producto151', 'Moda', 390.06, 26, 'Proveedor1', '2023-12-02', 'Almacén C')
# (152, 'Artículo152', 'Electrónica', 451.06, 10, 'Proveedor2', '2023-05-04', 'Almacén A')
# (153, 'Artículo153', 'Electrónica', 273.3, 41, 'Proveedor1', '2023-07-23', 'Almacén C')
# (154, 'Producto154', 'Deportes', 92.89, 16, 'Proveedor3', '2023-02-19', 'Almacén B')
# (155, 'Artículo155', 'Electrónica', 355.37, 19, 'Proveedor1', '2023-09-10', 'Almacén C')
# (156, 'Artículo156', 'Moda', 464.69, 9, 'Proveedor1', '2023-04-25', 'Almacén B')
# (157, 'Artículo157', 'Electrónica', 301.93, 77, 'Proveedor2', '2023-11-07', 'Almacén B')
# (158, 'Artículo158', 'Deportes', 29.22, 5, 'Proveedor3', '2023-05-16', 'Almacén C')
# (159, 'Objeto159', 'Electrónica', 412.52, 98, 'Proveedor1', '2023-09-06', 'Almacén A')
# (160, 'Producto160', 'Jardín', 160.15, 48, 'Proveedor3', '2023-12-11', 'Almacén A')
# (161, 'Producto161', 'Jardín', 231.51, 11, 'Proveedor3', '2023-11-04', 'Almacén A')
# (162, 'Producto162', 'Deportes', 437.08, 71, 'Proveedor1', '2023-11-25', 'Almacén A')
# (163, 'Producto163', 'Electrónica', 401.55, 8, 'Proveedor3', '2023-11-06', 'Almacén A')
# (164, 'Artículo164', 'Deportes', 361.26, 22, 'Proveedor3', '2023-10-01', 'Almacén C')
# (165, 'Artículo165', 'Jardín', 115.42, 91, 'Proveedor3', '2023-05-10', 'Almacén B')
# (166, 'Artículo166', 'Moda', 244.45, 70, 'Proveedor2', '2023-09-28', 'Almacén C')
# (167, 'Producto167', 'Moda', 280.94, 2, 'Proveedor3', '2023-04-26', 'Almacén B')
# (168, 'Objeto168', 'Jardín', 430.9, 15, 'Proveedor1', '2023-12-10', 'Almacén A')
# (169, 'Producto169', 'Moda', 21.99, 22, 'Proveedor3', '2023-07-25', 'Almacén C')
# (170, 'Objeto170', 'Jardín', 66.15, 38, 'Proveedor2', '2023-10-19', 'Almacén A')
# (171, 'Artículo171', 'Deportes', 375.85, 75, 'Proveedor2', '2023-02-26', 'Almacén A')
# (172, 'Producto172', 'Electrónica', 457.54, 23, 'Proveedor1', '2023-01-02', 'Almacén A')
# (173, 'Producto173', 'Deportes', 339.68, 39, 'Proveedor3', '2023-06-23', 'Almacén A')
# (174, 'Objeto174', 'Moda', 482.71, 88, 'Proveedor3', '2023-10-23', 'Almacén A')
# (175, 'Artículo175', 'Hogar', 93.47, 31, 'Proveedor2', '2023-07-16', 'Almacén A')
# (176, 'Producto176', 'Electrónica', 344.35, 36, 'Proveedor2', '2023-09-19', 'Almacén B')
# (177, 'Objeto177', 'Deportes', 358.6, 84, 'Proveedor2', '2023-01-27', 'Almacén B')
# (178, 'Producto178', 'Hogar', 474.39, 82, 'Proveedor3', '2023-02-23', 'Almacén B')
# (179, 'Producto179', 'Electrónica', 244.41, 25, 'Proveedor1', '2023-10-15', 'Almacén B')
# (180, 'Objeto180', 'Jardín', 464.57, 13, 'Proveedor1', '2023-01-10', 'Almacén A')
# (181, 'Artículo181', 'Electrónica', 115.15, 100, 'Proveedor1', '2023-03-13', 'Almacén A')
# (182, 'Producto182', 'Deportes', 131.06, 29, 'Proveedor1', '2023-08-02', 'Almacén A')
# (183, 'Producto183', 'Deportes', 319.14, 52, 'Proveedor2', '2023-09-25', 'Almacén C')
# (184, 'Objeto184', 'Hogar', 456.26, 17, 'Proveedor1', '2023-08-11', 'Almacén A')
# (185, 'Producto185', 'Electrónica', 404.21, 22, 'Proveedor3', '2023-07-01', 'Almacén C')
# (186, 'Artículo186', 'Hogar', 51.22, 13, 'Proveedor3', '2023-12-17', 'Almacén C')
# (187, 'Producto187', 'Moda', 203.22, 54, 'Proveedor3', '2023-04-19', 'Almacén A')
# (188, 'Objeto188', 'Deportes', 237.41, 10, 'Proveedor2', '2023-11-12', 'Almacén A')
# (189, 'Objeto189', 'Electrónica', 121.54, 56, 'Proveedor3', '2023-08-08', 'Almacén A')
# (190, 'Artículo190', 'Jardín', 253.45, 30, 'Proveedor1', '2023-11-18', 'Almacén A')
# (191, 'Objeto191', 'Jardín', 132.41, 52, 'Proveedor3', '2023-04-17', 'Almacén B')
# (192, 'Artículo192', 'Hogar', 304.86, 16, 'Proveedor1', '2023-02-19', 'Almacén B')
# (193, 'Artículo193', 'Moda', 137.09, 28, 'Proveedor1', '2023-01-13', 'Almacén C')
# (194, 'Objeto194', 'Jardín', 89.67, 97, 'Proveedor3', '2023-04-06', 'Almacén A')
# (195, 'Producto195', 'Moda', 92.24, 69, 'Proveedor3', '2023-06-26', 'Almacén A')
# (196, 'Producto196', 'Moda', 422.16, 17, 'Proveedor2', '2023-08-09', 'Almacén C')
# (197, 'Artículo197', 'Moda', 190.23, 54, 'Proveedor3', '2023-08-01', 'Almacén A')
# (198, 'Artículo198', 'Deportes', 384.75, 26, 'Proveedor3', '2023-08-03', 'Almacén C')
# (199, 'Objeto199', 'Deportes', 266.89, 81, 'Proveedor3', '2023-11-26', 'Almacén B')
# (200, 'Artículo200', 'Jardín', 254.7, 76, 'Proveedor2', '2023-10-04', 'Almacén A')
# (201, 'Artículo201', 'Moda', 87.3, 64, 'Proveedor1', '2023-07-27', 'Almacén B')
# (202, 'Artículo202', 'Deportes', 72.43, 65, 'Proveedor2', '2023-11-05', 'Almacén B')
# (203, 'Artículo203', 'Moda', 164.22, 70, 'Proveedor3', '2023-10-11', 'Almacén A')
# (204, 'Producto204', 'Deportes', 395.99, 100, 'Proveedor3', '2023-11-02', 'Almacén B')
# (205, 'Artículo205', 'Electrónica', 80.57, 87, 'Proveedor1', '2023-08-28', 'Almacén B')
# (206, 'Objeto206', 'Hogar', 477.14, 34, 'Proveedor1', '2023-09-20', 'Almacén B')
# (207, 'Producto207', 'Deportes', 369.4, 34, 'Proveedor2', '2023-03-12', 'Almacén C')
# (208, 'Producto208', 'Moda', 267.22, 57, 'Proveedor2', '2023-07-16', 'Almacén A')
# (209, 'Producto209', 'Hogar', 464.9, 95, 'Proveedor3', '2023-06-23', 'Almacén B')
# (210, 'Objeto210', 'Deportes', 305.28, 95, 'Proveedor2', '2023-01-02', 'Almacén B')
# (211, 'Artículo211', 'Deportes', 184.25, 14, 'Proveedor2', '2023-09-26', 'Almacén C')
# (212, 'Objeto212', 'Electrónica', 51.51, 10, 'Proveedor2', '2023-06-11', 'Almacén C')
# (213, 'Producto213', 'Moda', 36.5, 62, 'Proveedor2', '2023-01-17', 'Almacén A')
# (214, 'Objeto214', 'Hogar', 465.75, 82, 'Proveedor1', '2023-02-27', 'Almacén C')
# (215, 'Objeto215', 'Jardín', 172.19, 18, 'Proveedor1', '2023-04-16', 'Almacén B')
# (216, 'Artículo216', 'Electrónica', 17.8, 91, 'Proveedor1', '2023-01-15', 'Almacén A')
# (217, 'Objeto217', 'Electrónica', 488.94, 22, 'Proveedor1', '2023-07-03', 'Almacén C')
# (218, 'Artículo218', 'Deportes', 370.26, 88, 'Proveedor3', '2023-11-17', 'Almacén A')
# (219, 'Producto219', 'Moda', 328.33, 3, 'Proveedor2', '2023-02-25', 'Almacén B')
# (220, 'Artículo220', 'Hogar', 131.41, 75, 'Proveedor2', '2023-12-25', 'Almacén C')
# (221, 'Objeto221', 'Jardín', 228.83, 62, 'Proveedor1', '2023-07-03', 'Almacén C')
# (222, 'Producto222', 'Jardín', 212.75, 55, 'Proveedor3', '2023-04-12', 'Almacén B')
# (223, 'Artículo223', 'Deportes', 186.2, 96, 'Proveedor2', '2023-01-08', 'Almacén B')
# (224, 'Producto224', 'Electrónica', 77.72, 25, 'Proveedor2', '2023-04-06', 'Almacén C')
# (225, 'Objeto225', 'Deportes', 428.52, 67, 'Proveedor3', '2023-01-13', 'Almacén C')
# (226, 'Producto226', 'Moda', 421.37, 38, 'Proveedor2', '2023-09-07', 'Almacén C')
# (227, 'Artículo227', 'Moda', 139.71, 57, 'Proveedor1', '2023-10-23', 'Almacén B')
# (228, 'Producto228', 'Hogar', 232.4, 75, 'Proveedor3', '2023-03-05', 'Almacén A')
# (229, 'Artículo229', 'Moda', 168.92, 43, 'Proveedor3', '2023-04-15', 'Almacén A')
# (230, 'Producto230', 'Electrónica', 343.35, 27, 'Proveedor3', '2023-04-07', 'Almacén C')
# (231, 'Objeto231', 'Deportes', 238.55, 47, 'Proveedor3', '2023-06-27', 'Almacén A')
# (232, 'Objeto232', 'Electrónica', 240.09, 14, 'Proveedor2', '2023-08-12', 'Almacén B')
# (233, 'Objeto233', 'Hogar', 238.47, 24, 'Proveedor1', '2023-06-27', 'Almacén B')
# (234, 'Objeto234', 'Deportes', 179.4, 70, 'Proveedor1', '2023-10-16', 'Almacén B')
# (235, 'Producto235', 'Moda', 301.03, 98, 'Proveedor2', '2023-06-10', 'Almacén C')
# (236, 'Objeto236', 'Hogar', 413.24, 5, 'Proveedor3', '2023-12-16', 'Almacén C')
# (237, 'Producto237', 'Electrónica', 155.77, 29, 'Proveedor1', '2023-06-20', 'Almacén C')
# (238, 'Objeto238', 'Jardín', 38.02, 97, 'Proveedor3', '2023-07-14', 'Almacén B')
# (239, 'Producto239', 'Electrónica', 40.3, 97, 'Proveedor2', '2023-10-11', 'Almacén C')
# (240, 'Producto240', 'Moda', 249.07, 44, 'Proveedor2', '2023-06-21', 'Almacén B')
# (241, 'Artículo241', 'Hogar', 350, 27, 'Proveedor3', '2023-02-25', 'Almacén A')
# (242, 'Artículo242', 'Hogar', 262.47, 96, 'Proveedor1', '2023-04-25', 'Almacén B')
# (243, 'Producto243', 'Moda', 120.72, 77, 'Proveedor2', '2023-12-01', 'Almacén A')
# (244, 'Artículo244', 'Deportes', 308.73, 3, 'Proveedor2', '2023-09-24', 'Almacén C')
# (245, 'Producto245', 'Electrónica', 309.59, 73, 'Proveedor1', '2023-07-06', 'Almacén A')
# (246, 'Objeto246', 'Moda', 442.21, 6, 'Proveedor1', '2023-10-18', 'Almacén A')
# (247, 'Objeto247', 'Jardín', 431.29, 18, 'Proveedor3', '2023-03-17', 'Almacén C')
# (248, 'Objeto248', 'Hogar', 487.74, 42, 'Proveedor1', '2023-12-11', 'Almacén C')
# (249, 'Artículo249', 'Deportes', 194.38, 61, 'Proveedor2', '2023-02-12', 'Almacén C')
# (250, 'Artículo250', 'Deportes', 51.05, 94, 'Proveedor3', '2023-12-18', 'Almacén B')
# (251, 'Artículo251', 'Jardín', 79.65, 77, 'Proveedor1', '2023-08-27', 'Almacén B')
# (252, 'Objeto252', 'Electrónica', 132.12, 6, 'Proveedor1', '2023-05-14', 'Almacén C')
# (253, 'Artículo253', 'Hogar', 157.26, 76, 'Proveedor3', '2023-11-27', 'Almacén A')
# (254, 'Producto254', 'Moda', 98.56, 43, 'Proveedor3', '2023-09-22', 'Almacén A')
# (255, 'Objeto255', 'Deportes', 263.99, 79, 'Proveedor2', '2023-07-09', 'Almacén B')
# (256, 'Producto256', 'Hogar', 128.18, 71, 'Proveedor3', '2023-10-27', 'Almacén C')
# (257, 'Objeto257', 'Deportes', 448.36, 63, 'Proveedor2', '2023-06-22', 'Almacén C')
# (258, 'Producto258', 'Hogar', 132.56, 9, 'Proveedor2', '2023-07-16', 'Almacén B')
# (259, 'Artículo259', 'Deportes', 237.84, 7, 'Proveedor3', '2023-07-19', 'Almacén C')
# (260, 'Artículo260', 'Electrónica', 13.54, 96, 'Proveedor3', '2023-10-23', 'Almacén A')
# (261, 'Producto261', 'Deportes', 280.39, 90, 'Proveedor2', '2023-06-09', 'Almacén A')
# (262, 'Objeto262', 'Electrónica', 303.66, 24, 'Proveedor1', '2023-10-16', 'Almacén C')
# (263, 'Objeto263', 'Deportes', 200.04, 91, 'Proveedor3', '2023-10-05', 'Almacén C')
# (264, 'Objeto264', 'Electrónica', 64.34, 31, 'Proveedor2', '2023-03-16', 'Almacén C')
# (265, 'Artículo265', 'Hogar', 115.43, 21, 'Proveedor1', '2023-06-21', 'Almacén B')
# (266, 'Producto266', 'Deportes', 377.64, 10, 'Proveedor1', '2023-08-15', 'Almacén C')
# (267, 'Artículo267', 'Jardín', 112.56, 23, 'Proveedor1', '2023-10-21', 'Almacén A')
# (268, 'Artículo268', 'Hogar', 401.62, 46, 'Proveedor3', '2023-06-03', 'Almacén C')
# (269, 'Objeto269', 'Jardín', 445.91, 37, 'Proveedor2', '2023-06-03', 'Almacén B')
# (270, 'Producto270', 'Deportes', 306.76, 6, 'Proveedor1', '2023-12-06', 'Almacén C')
# (271, 'Artículo271', 'Moda', 445.89, 60, 'Proveedor3', '2023-10-03', 'Almacén B')
# (272, 'Objeto272', 'Jardín', 311.96, 48, 'Proveedor2', '2023-07-24', 'Almacén C')
# (273, 'Objeto273', 'Hogar', 472.42, 33, 'Proveedor3', '2023-12-16', 'Almacén C')
# (274, 'Objeto274', 'Hogar', 494.64, 37, 'Proveedor1', '2023-11-05', 'Almacén A')
# (275, 'Objeto275', 'Electrónica', 388.65, 5, 'Proveedor2', '2023-10-02', 'Almacén C')
# (276, 'Artículo276', 'Electrónica', 18.67, 33, 'Proveedor3', '2023-04-09', 'Almacén A')
# (277, 'Artículo277', 'Jardín', 405.42, 48, 'Proveedor3', '2023-07-01', 'Almacén B')
# (278, 'Artículo278', 'Jardín', 404.31, 15, 'Proveedor3', '2023-09-19', 'Almacén C')
# (279, 'Objeto279', 'Jardín', 390.2, 46, 'Proveedor2', '2023-07-07', 'Almacén B')
# (280, 'Objeto280', 'Deportes', 394.59, 65, 'Proveedor1', '2023-08-04', 'Almacén A')
# (281, 'Objeto281', 'Moda', 494.44, 11, 'Proveedor2', '2023-07-20', 'Almacén C')
# (282, 'Objeto282', 'Hogar', 493.82, 17, 'Proveedor3', '2023-09-21', 'Almacén B')
# (283, 'Producto283', 'Moda', 328.51, 2, 'Proveedor3', '2023-02-23', 'Almacén A')
# (284, 'Producto284', 'Jardín', 153.97, 56, 'Proveedor2', '2023-02-06', 'Almacén A')
# (285, 'Producto285', 'Hogar', 42.68, 56, 'Proveedor2', '2023-02-08', 'Almacén B')
# (286, 'Artículo286', 'Moda', 273.71, 18, 'Proveedor2', '2023-10-09', 'Almacén B')
# (287, 'Artículo287', 'Jardín', 107.66, 100, 'Proveedor1', '2023-01-13', 'Almacén B')
# (288, 'Producto288', 'Hogar', 402.61, 29, 'Proveedor3', '2023-04-21', 'Almacén C')
# (289, 'Artículo289', 'Hogar', 486.29, 78, 'Proveedor2', '2023-07-03', 'Almacén B')
# (290, 'Objeto290', 'Hogar', 163.89, 83, 'Proveedor1', '2023-04-11', 'Almacén B')
# (291, 'Objeto291', 'Deportes', 62.51, 89, 'Proveedor3', '2023-09-24', 'Almacén C')
# (292, 'Producto292', 'Electrónica', 191.18, 60, 'Proveedor3', '2023-01-23', 'Almacén B')
# (293, 'Producto293', 'Electrónica', 239.48, 16, 'Proveedor3', '2023-08-27', 'Almacén B')
# (294, 'Artículo294', 'Moda', 468.89, 29, 'Proveedor1', '2023-10-26', 'Almacén B')
# (295, 'Objeto295', 'Hogar', 19.2, 62, 'Proveedor2', '2023-10-02', 'Almacén B')
# (296, 'Artículo296', 'Jardín', 167.51, 91, 'Proveedor2', '2023-02-03', 'Almacén C')
# (297, 'Objeto297', 'Moda', 444.99, 76, 'Proveedor3', '2023-11-08', 'Almacén A')
# (298, 'Producto298', 'Deportes', 133.94, 38, 'Proveedor2', '2023-08-01', 'Almacén B')
# (299, 'Objeto299', 'Hogar', 126.85, 18, 'Proveedor3', '2023-10-27', 'Almacén B')
# (300, 'Artículo300', 'Hogar', 244.05, 51, 'Proveedor3', '2023-04-09', 'Almacén A')
# (301, 'Producto301', 'Moda', 43.95, 87, 'Proveedor2', '2023-09-02', 'Almacén B')
# (302, 'Artículo302', 'Electrónica', 19.94, 41, 'Proveedor2', '2023-03-14', 'Almacén A')
# (303, 'Objeto303', 'Jardín', 197.64, 97, 'Proveedor1', '2023-06-11', 'Almacén B')
# (304, 'Artículo304', 'Deportes', 491.39, 90, 'Proveedor3', '2023-02-12', 'Almacén B')
# (305, 'Objeto305', 'Jardín', 382.78, 30, 'Proveedor3', '2023-12-26', 'Almacén B')
# (306, 'Producto306', 'Moda', 458.5, 60, 'Proveedor2', '2023-11-10', 'Almacén C')
# (307, 'Objeto307', 'Moda', 10.7, 5, 'Proveedor1', '2023-09-22', 'Almacén A')
# (308, 'Producto308', 'Moda', 166.18, 72, 'Proveedor3', '2023-02-04', 'Almacén A')
# (309, 'Artículo309', 'Deportes', 329.24, 5, 'Proveedor3', '2023-06-24', 'Almacén B')
# (310, 'Artículo310', 'Hogar', 432.15, 55, 'Proveedor1', '2023-03-05', 'Almacén A')
# (311, 'Producto311', 'Moda', 95.85, 44, 'Proveedor3', '2023-06-02', 'Almacén C')
# (312, 'Objeto312', 'Moda', 18.15, 64, 'Proveedor1', '2023-01-03', 'Almacén A')
# (313, 'Objeto313', 'Moda', 309.92, 28, 'Proveedor3', '2023-12-10', 'Almacén A')
# (314, 'Objeto314', 'Hogar', 66.55, 23, 'Proveedor3', '2023-08-02', 'Almacén C')
# (315, 'Producto315', 'Deportes', 449.18, 85, 'Proveedor1', '2023-08-07', 'Almacén C')
# (316, 'Objeto316', 'Deportes', 447.96, 89, 'Proveedor2', '2023-03-24', 'Almacén B')
# (317, 'Objeto317', 'Deportes', 421.39, 65, 'Proveedor1', '2023-07-07', 'Almacén C')
# (318, 'Objeto318', 'Hogar', 423.55, 84, 'Proveedor2', '2023-09-13', 'Almacén A')
# (319, 'Artículo319', 'Hogar', 178.71, 61, 'Proveedor1', '2023-05-05', 'Almacén B')
# (320, 'Producto320', 'Moda', 379.93, 33, 'Proveedor3', '2023-03-04', 'Almacén C')
# (321, 'Artículo321', 'Electrónica', 481.47, 16, 'Proveedor2', '2023-11-14', 'Almacén A')
# (322, 'Producto322', 'Jardín', 183.84, 62, 'Proveedor1', '2023-08-11', 'Almacén C')
# (323, 'Producto323', 'Hogar', 417.44, 6, 'Proveedor2', '2023-05-09', 'Almacén B')
# (324, 'Producto324', 'Moda', 448.57, 38, 'Proveedor2', '2023-04-10', 'Almacén C')
# (325, 'Artículo325', 'Deportes', 12.84, 34, 'Proveedor2', '2023-09-02', 'Almacén A')
# (326, 'Objeto326', 'Hogar', 361.55, 38, 'Proveedor2', '2023-09-20', 'Almacén A')
# (327, 'Objeto327', 'Deportes', 240.41, 19, 'Proveedor1', '2023-02-04', 'Almacén C')
# (328, 'Artículo328', 'Moda', 436.09, 67, 'Proveedor3', '2023-02-08', 'Almacén B')
# (329, 'Objeto329', 'Deportes', 497.59, 66, 'Proveedor2', '2023-12-26', 'Almacén A')
# (330, 'Artículo330', 'Jardín', 175.19, 98, 'Proveedor2', '2023-07-21', 'Almacén B')
# (331, 'Producto331', 'Jardín', 405.87, 21, 'Proveedor2', '2023-12-13', 'Almacén C')
# (332, 'Producto332', 'Moda', 12.3, 49, 'Proveedor1', '2023-04-20', 'Almacén B')
# (333, 'Producto333', 'Deportes', 466.86, 82, 'Proveedor3', '2023-03-09', 'Almacén A')
# (334, 'Artículo334', 'Jardín', 335.4, 96, 'Proveedor3', '2023-07-24', 'Almacén A')
# (335, 'Objeto335', 'Moda', 213.97, 93, 'Proveedor3', '2023-05-22', 'Almacén B')
# (336, 'Objeto336', 'Hogar', 134.89, 80, 'Proveedor3', '2023-01-10', 'Almacén C')
# (337, 'Artículo337', 'Deportes', 264.01, 32, 'Proveedor1', '2023-04-16', 'Almacén B')
# (338, 'Objeto338', 'Electrónica', 59.57, 84, 'Proveedor2', '2023-08-12', 'Almacén B')
# (339, 'Artículo339', 'Deportes', 185.39, 82, 'Proveedor1', '2023-06-15', 'Almacén A')
# (340, 'Producto340', 'Electrónica', 485.19, 90, 'Proveedor3', '2023-02-10', 'Almacén C')
# (341, 'Artículo341', 'Deportes', 265.97, 66, 'Proveedor3', '2023-08-23', 'Almacén A')
# (342, 'Artículo342', 'Deportes', 52.46, 21, 'Proveedor2', '2023-11-17', 'Almacén A')
# (343, 'Artículo343', 'Moda', 447.15, 22, 'Proveedor2', '2023-02-19', 'Almacén C')
# (344, 'Objeto344', 'Jardín', 127.69, 18, 'Proveedor2', '2023-09-16', 'Almacén B')
# (345, 'Objeto345', 'Moda', 60.16, 84, 'Proveedor3', '2023-03-21', 'Almacén A')
# (346, 'Objeto346', 'Electrónica', 27.74, 78, 'Proveedor1', '2023-12-08', 'Almacén A')
# (347, 'Artículo347', 'Moda', 362.59, 30, 'Proveedor3', '2023-04-21', 'Almacén A')
# (348, 'Objeto348', 'Jardín', 490.13, 48, 'Proveedor3', '2023-01-17', 'Almacén A')
# (349, 'Producto349', 'Electrónica', 98.69, 54, 'Proveedor2', '2023-09-20', 'Almacén C')
# (350, 'Artículo350', 'Hogar', 43.56, 33, 'Proveedor1', '2023-04-09', 'Almacén C')
# (351, 'Objeto351', 'Deportes', 50.18, 59, 'Proveedor3', '2023-07-06', 'Almacén C')
# (352, 'Objeto352', 'Electrónica', 150.43, 3, 'Proveedor3', '2023-02-21', 'Almacén C')
# (353, 'Artículo353', 'Hogar', 72.89, 28, 'Proveedor2', '2023-12-25', 'Almacén C')
# (354, 'Artículo354', 'Electrónica', 294.17, 37, 'Proveedor1', '2023-11-26', 'Almacén B')
# (355, 'Artículo355', 'Electrónica', 439.72, 99, 'Proveedor3', '2023-02-03', 'Almacén A')
# (356, 'Artículo356', 'Moda', 315.79, 66, 'Proveedor2', '2023-08-21', 'Almacén B')
# (357, 'Objeto357', 'Jardín', 96.7, 99, 'Proveedor2', '2023-02-15', 'Almacén B')
# (358, 'Artículo358', 'Electrónica', 32.4, 25, 'Proveedor2', '2023-12-24', 'Almacén A')
# (359, 'Producto359', 'Hogar', 78.75, 60, 'Proveedor1', '2023-08-17', 'Almacén B')
# (360, 'Producto360', 'Moda', 75.99, 100, 'Proveedor2', '2023-02-02', 'Almacén C')
# (361, 'Producto361', 'Electrónica', 265.73, 56, 'Proveedor3', '2023-07-12', 'Almacén B')
# (362, 'Producto362', 'Jardín', 302.18, 32, 'Proveedor1', '2023-10-21', 'Almacén A')
# (363, 'Producto363', 'Moda', 460.28, 64, 'Proveedor2', '2023-05-03', 'Almacén A')
# (364, 'Objeto364', 'Hogar', 180.44, 80, 'Proveedor2', '2023-05-23', 'Almacén B')
# (365, 'Producto365', 'Deportes', 283.32, 69, 'Proveedor3', '2023-11-16', 'Almacén A')
# (366, 'Producto366', 'Jardín', 118.21, 74, 'Proveedor2', '2023-12-27', 'Almacén B')
# (367, 'Producto367', 'Deportes', 136.89, 57, 'Proveedor2', '2023-11-13', 'Almacén C')
# (368, 'Producto368', 'Deportes', 146.71, 80, 'Proveedor3', '2023-06-17', 'Almacén C')
# (369, 'Objeto369', 'Electrónica', 316.37, 77, 'Proveedor1', '2023-12-15', 'Almacén A')
# (370, 'Producto370', 'Jardín', 324.86, 70, 'Proveedor1', '2023-02-13', 'Almacén B')
# (371, 'Artículo371', 'Electrónica', 150.75, 60, 'Proveedor3', '2023-01-24', 'Almacén A')
# (372, 'Producto372', 'Deportes', 148.3, 4, 'Proveedor1', '2023-10-18', 'Almacén B')
# (373, 'Producto373', 'Deportes', 474.94, 52, 'Proveedor3', '2023-05-25', 'Almacén B')
# (374, 'Artículo374', 'Jardín', 161.37, 4, 'Proveedor1', '2023-07-26', 'Almacén C')
# (375, 'Objeto375', 'Moda', 46.21, 56, 'Proveedor3', '2023-01-16', 'Almacén A')
# (376, 'Objeto376', 'Electrónica', 144.44, 70, 'Proveedor2', '2023-04-08', 'Almacén B')
# (377, 'Artículo377', 'Moda', 353, 67, 'Proveedor1', '2023-01-05', 'Almacén C')
# (378, 'Objeto378', 'Jardín', 179.14, 94, 'Proveedor2', '2023-10-10', 'Almacén B')
# (379, 'Producto379', 'Moda', 17.48, 74, 'Proveedor2', '2023-08-19', 'Almacén B')
# (380, 'Artículo380', 'Deportes', 43.44, 30, 'Proveedor2', '2023-12-01', 'Almacén B')
# (381, 'Artículo381', 'Hogar', 76.55, 100, 'Proveedor3', '2023-09-23', 'Almacén C')
# (382, 'Artículo382', 'Moda', 472.4, 65, 'Proveedor2', '2023-01-17', 'Almacén A')
# (383, 'Objeto383', 'Moda', 170.46, 10, 'Proveedor3', '2023-04-09', 'Almacén B')
# (384, 'Producto384', 'Deportes', 93.15, 47, 'Proveedor2', '2023-05-16', 'Almacén B')
# (385, 'Producto385', 'Hogar', 292.29, 66, 'Proveedor3', '2023-10-04', 'Almacén C')
# (386, 'Objeto386', 'Hogar', 451.6, 30, 'Proveedor1', '2023-12-01', 'Almacén C')
# (387, 'Producto387', 'Deportes', 197.87, 95, 'Proveedor3', '2023-11-16', 'Almacén A')
# (388, 'Producto388', 'Moda', 374.53, 44, 'Proveedor3', '2023-04-08', 'Almacén B')
# (389, 'Objeto389', 'Jardín', 341.22, 90, 'Proveedor1', '2023-11-03', 'Almacén A')
# (390, 'Artículo390', 'Deportes', 422.81, 79, 'Proveedor1', '2023-01-15', 'Almacén A')
# (391, 'Objeto391', 'Electrónica', 307.16, 5, 'Proveedor2', '2023-03-02', 'Almacén C')
# (392, 'Objeto392', 'Moda', 249.12, 58, 'Proveedor2', '2023-06-21', 'Almacén A')
# (393, 'Producto393', 'Deportes', 422.04, 28, 'Proveedor3', '2023-11-03', 'Almacén B')
# (394, 'Producto394', 'Moda', 12.19, 87, 'Proveedor2', '2023-05-24', 'Almacén A')
# (395, 'Producto395', 'Hogar', 76.27, 79, 'Proveedor3', '2023-03-25', 'Almacén A')
# (396, 'Producto396', 'Jardín', 158.93, 39, 'Proveedor1', '2023-06-16', 'Almacén A')
# (397, 'Artículo397', 'Hogar', 208.12, 90, 'Proveedor3', '2023-01-28', 'Almacén A')
# (398, 'Artículo398', 'Moda', 449.89, 96, 'Proveedor2', '2023-07-18', 'Almacén A')
# (399, 'Producto399', 'Electrónica', 165.9, 84, 'Proveedor1', '2023-03-02', 'Almacén C')
# (400, 'Producto400', 'Hogar', 327.45, 46, 'Proveedor2', '2023-01-03', 'Almacén A')
# (401, 'Objeto401', 'Jardín', 46.51, 6, 'Proveedor3', '2023-04-18', 'Almacén C')
# (402, 'Objeto402', 'Deportes', 172.66, 95, 'Proveedor1', '2023-10-14', 'Almacén C')
# (403, 'Objeto403', 'Hogar', 365.34, 31, 'Proveedor1', '2023-03-17', 'Almacén B')
# (404, 'Artículo404', 'Moda', 36.69, 59, 'Proveedor2', '2023-09-21', 'Almacén A')
# (405, 'Artículo405', 'Hogar', 228.68, 74, 'Proveedor1', '2023-05-22', 'Almacén A')
# (406, 'Producto406', 'Deportes', 302.96, 14, 'Proveedor3', '2023-09-28', 'Almacén C')
# (407, 'Objeto407', 'Jardín', 133.49, 61, 'Proveedor1', '2023-01-12', 'Almacén B')
# (408, 'Objeto408', 'Moda', 154.97, 77, 'Proveedor1', '2023-04-07', 'Almacén A')
# (409, 'Artículo409', 'Moda', 186.63, 67, 'Proveedor2', '2023-07-17', 'Almacén B')
# (410, 'Producto410', 'Hogar', 186.55, 22, 'Proveedor2', '2023-07-23', 'Almacén A')
# (411, 'Artículo411', 'Hogar', 150.78, 13, 'Proveedor1', '2023-03-05', 'Almacén B')
# (412, 'Objeto412', 'Electrónica', 177.04, 69, 'Proveedor3', '2023-08-20', 'Almacén B')
# (413, 'Producto413', 'Deportes', 143.57, 100, 'Proveedor2', '2023-07-13', 'Almacén A')
# (414, 'Producto414', 'Hogar', 76.3, 18, 'Proveedor3', '2023-04-01', 'Almacén C')
# (415, 'Artículo415', 'Moda', 332.31, 94, 'Proveedor3', '2023-08-08', 'Almacén B')
# (416, 'Objeto416', 'Jardín', 22.77, 11, 'Proveedor3', '2023-05-08', 'Almacén C')
# (417, 'Artículo417', 'Moda', 361.06, 39, 'Proveedor3', '2023-04-02', 'Almacén B')
# (418, 'Artículo418', 'Electrónica', 125.65, 34, 'Proveedor3', '2023-11-20', 'Almacén C')
# (419, 'Producto419', 'Jardín', 340.6, 31, 'Proveedor3', '2023-02-02', 'Almacén B')
# (420, 'Artículo420', 'Hogar', 439.67, 83, 'Proveedor2', '2023-03-17', 'Almacén B')
# (421, 'Artículo421', 'Deportes', 81.1, 74, 'Proveedor2', '2023-11-21', 'Almacén C')
# (422, 'Objeto422', 'Jardín', 16.61, 100, 'Proveedor3', '2023-01-09', 'Almacén B')
# (423, 'Artículo423', 'Jardín', 122.77, 1, 'Proveedor3', '2023-12-28', 'Almacén A')
# (424, 'Artículo424', 'Deportes', 406.37, 74, 'Proveedor1', '2023-09-09', 'Almacén B')
# (425, 'Objeto425', 'Hogar', 258.71, 88, 'Proveedor3', '2023-09-24', 'Almacén B')
# (426, 'Artículo426', 'Electrónica', 451.68, 60, 'Proveedor1', '2023-08-18', 'Almacén C')
# (427, 'Producto427', 'Hogar', 330.63, 45, 'Proveedor2', '2023-10-19', 'Almacén B')
# (428, 'Artículo428', 'Moda', 113.91, 66, 'Proveedor1', '2023-09-10', 'Almacén C')
# (429, 'Artículo429', 'Deportes', 323.51, 89, 'Proveedor3', '2023-06-10', 'Almacén B')
# (430, 'Producto430', 'Electrónica', 248.97, 93, 'Proveedor1', '2023-02-26', 'Almacén C')
# (431, 'Artículo431', 'Moda', 364.05, 63, 'Proveedor2', '2023-05-10', 'Almacén B')
# (432, 'Objeto432', 'Jardín', 105.3, 68, 'Proveedor3', '2023-09-05', 'Almacén B')
# (433, 'Artículo433', 'Deportes', 151.89, 31, 'Proveedor3', '2023-09-13', 'Almacén B')
# (434, 'Objeto434', 'Hogar', 419.34, 93, 'Proveedor2', '2023-03-27', 'Almacén A')
# (435, 'Objeto435', 'Deportes', 89.97, 2, 'Proveedor2', '2023-08-09', 'Almacén A')
# (436, 'Artículo436', 'Moda', 35.27, 30, 'Proveedor2', '2023-05-17', 'Almacén A')
# (437, 'Producto437', 'Electrónica', 285.19, 26, 'Proveedor1', '2023-02-02', 'Almacén B')
# (438, 'Objeto438', 'Hogar', 370.42, 81, 'Proveedor2', '2023-02-09', 'Almacén A')
# (439, 'Producto439', 'Moda', 69.15, 42, 'Proveedor2', '2023-01-20', 'Almacén C')
# (440, 'Producto440', 'Electrónica', 235.77, 58, 'Proveedor3', '2023-09-24', 'Almacén B')
# (441, 'Artículo441', 'Jardín', 177.98, 2, 'Proveedor1', '2023-11-13', 'Almacén A')
# (442, 'Artículo442', 'Moda', 464.47, 37, 'Proveedor1', '2023-02-01', 'Almacén C')
# (443, 'Producto443', 'Jardín', 200.37, 45, 'Proveedor2', '2023-08-14', 'Almacén B')
# (444, 'Objeto444', 'Electrónica', 251.47, 23, 'Proveedor1', '2023-10-07', 'Almacén A')
# (445, 'Artículo445', 'Jardín', 366.08, 73, 'Proveedor1', '2023-08-15', 'Almacén B')
# (446, 'Objeto446', 'Moda', 383.08, 48, 'Proveedor1', '2023-01-23', 'Almacén B')
# (447, 'Artículo447', 'Electrónica', 477.17, 35, 'Proveedor3', '2023-11-09', 'Almacén B')
# (448, 'Producto448', 'Moda', 95.51, 89, 'Proveedor2', '2023-08-20', 'Almacén B')
# (449, 'Objeto449', 'Deportes', 154.24, 97, 'Proveedor2', '2023-04-07', 'Almacén C')
# (450, 'Objeto450', 'Moda', 300.62, 45, 'Proveedor3', '2023-11-01', 'Almacén B')
# (451, 'Producto451', 'Deportes', 182.02, 84, 'Proveedor3', '2023-02-08', 'Almacén B')
# (452, 'Producto452', 'Jardín', 116.06, 12, 'Proveedor1', '2023-11-14', 'Almacén B')
# (453, 'Artículo453', 'Electrónica', 185.02, 96, 'Proveedor2', '2023-05-24', 'Almacén A')
# (454, 'Producto454', 'Hogar', 134.55, 41, 'Proveedor1', '2023-11-06', 'Almacén C')
# (455, 'Producto455', 'Deportes', 136.48, 82, 'Proveedor2', '2023-04-20', 'Almacén B')
# (456, 'Producto456', 'Deportes', 342.6, 19, 'Proveedor2', '2023-07-03', 'Almacén B')
# (457, 'Producto457', 'Moda', 290.56, 5, 'Proveedor3', '2023-05-19', 'Almacén A')
# (458, 'Artículo458', 'Electrónica', 76.34, 99, 'Proveedor2', '2023-08-03', 'Almacén A')
# (459, 'Artículo459', 'Deportes', 260.35, 21, 'Proveedor2', '2023-01-24', 'Almacén B')
# (460, 'Objeto460', 'Deportes', 394.21, 25, 'Proveedor2', '2023-11-24', 'Almacén B')
# (461, 'Artículo461', 'Hogar', 50.32, 48, 'Proveedor3', '2023-07-15', 'Almacén A')
# (462, 'Objeto462', 'Hogar', 162.24, 66, 'Proveedor3', '2023-10-19', 'Almacén C')
# (463, 'Artículo463', 'Moda', 397.28, 15, 'Proveedor2', '2023-03-04', 'Almacén B')
# (464, 'Producto464', 'Moda', 42.75, 19, 'Proveedor2', '2023-10-10', 'Almacén A')
# (465, 'Artículo465', 'Deportes', 39.75, 91, 'Proveedor1', '2023-11-16', 'Almacén B')
# (466, 'Producto466', 'Moda', 263.44, 39, 'Proveedor2', '2023-03-13', 'Almacén C')
# (467, 'Producto467', 'Jardín', 417.86, 90, 'Proveedor3', '2023-09-27', 'Almacén A')
# (468, 'Producto468', 'Hogar', 16.89, 96, 'Proveedor2', '2023-02-23', 'Almacén C')
# (469, 'Artículo469', 'Moda', 214.49, 41, 'Proveedor2', '2023-04-10', 'Almacén B')
# (470, 'Artículo470', 'Jardín', 410.98, 12, 'Proveedor1', '2023-01-25', 'Almacén C')
# (471, 'Objeto471', 'Hogar', 417.25, 9, 'Proveedor3', '2023-10-04', 'Almacén B')
# (472, 'Producto472', 'Jardín', 210.04, 86, 'Proveedor2', '2023-11-09', 'Almacén C')
# (473, 'Producto473', 'Electrónica', 371.42, 99, 'Proveedor2', '2023-03-23', 'Almacén B')
# (474, 'Artículo474', 'Electrónica', 405.97, 55, 'Proveedor1', '2023-09-04', 'Almacén A')
# (475, 'Artículo475', 'Moda', 446.71, 44, 'Proveedor2', '2023-09-18', 'Almacén C')
# (476, 'Producto476', 'Hogar', 469.3, 13, 'Proveedor3', '2023-01-14', 'Almacén C')
# (477, 'Producto477', 'Jardín', 242.7, 93, 'Proveedor2', '2023-03-08', 'Almacén B')
# (478, 'Producto478', 'Deportes', 118.07, 16, 'Proveedor2', '2023-03-19', 'Almacén B')
# (479, 'Artículo479', 'Hogar', 450.61, 7, 'Proveedor1', '2023-05-16', 'Almacén B')
# (480, 'Objeto480', 'Hogar', 490.13, 7, 'Proveedor1', '2023-10-26', 'Almacén A')
# (481, 'Objeto481', 'Electrónica', 93.39, 85, 'Proveedor1', '2023-02-12', 'Almacén A')
# (482, 'Artículo482', 'Hogar', 264.83, 80, 'Proveedor2', '2023-09-01', 'Almacén B')
# (483, 'Artículo483', 'Moda', 370.97, 84, 'Proveedor2', '2023-09-23', 'Almacén B')
# (484, 'Objeto484', 'Electrónica', 296.44, 57, 'Proveedor3', '2023-05-17', 'Almacén B')
# (485, 'Objeto485', 'Moda', 457.04, 95, 'Proveedor2', '2023-02-17', 'Almacén C')
# (486, 'Artículo486', 'Moda', 117.52, 18, 'Proveedor3', '2023-05-18', 'Almacén A')
# (487, 'Artículo487', 'Hogar', 297.22, 34, 'Proveedor2', '2023-07-02', 'Almacén B')
# (488, 'Objeto488', 'Electrónica', 65.5, 16, 'Proveedor2', '2023-08-17', 'Almacén A')
# (489, 'Objeto489', 'Hogar', 43.03, 61, 'Proveedor2', '2023-11-03', 'Almacén C')
# (490, 'Artículo490', 'Deportes', 386.27, 50, 'Proveedor3', '2023-11-25', 'Almacén A')
# (491, 'Objeto491', 'Hogar', 352.07, 26, 'Proveedor2', '2023-06-23', 'Almacén B')
# (492, 'Objeto492', 'Electrónica', 466.55, 50, 'Proveedor2', '2023-07-24', 'Almacén B')
# (493, 'Artículo493', 'Deportes', 289.35, 98, 'Proveedor2', '2023-09-10', 'Almacén B')
# (494, 'Producto494', 'Moda', 189.36, 86, 'Proveedor3', '2023-09-22', 'Almacén A')
# (495, 'Artículo495', 'Jardín', 496.6, 30, 'Proveedor3', '2023-06-19', 'Almacén B')
# (496, 'Artículo496', 'Hogar', 326.07, 70, 'Proveedor2', '2023-02-07', 'Almacén C')
# (497, 'Artículo497', 'Jardín', 50.41, 11, 'Proveedor2', '2023-01-10', 'Almacén A')
# (498, 'Artículo498', 'Electrónica', 469.22, 82, 'Proveedor3', '2023-04-01', 'Almacén A')
# (499, 'Artículo499', 'Hogar', 63.38, 27, 'Proveedor1', '2023-03-17', 'Almacén A')
# (500, 'Artículo500', 'Electrónica', 410.56, 99, 'Proveedor2', '2023-07-10', 'Almacén C')
# (501, 'Artículo501', 'Electrónica', 133.53, 15, 'Proveedor2', '2023-08-14', 'Almacén B')
# (502, 'Objeto502', 'Deportes', 307.44, 33, 'Proveedor2', '2023-03-03', 'Almacén A')
# (503, 'Producto503', 'Jardín', 276.82, 21, 'Proveedor3', '2023-08-27', 'Almacén A')
# (504, 'Artículo504', 'Deportes', 10.37, 86, 'Proveedor3', '2023-06-13', 'Almacén A')
# (505, 'Artículo505', 'Jardín', 205.86, 9, 'Proveedor2', '2023-02-15', 'Almacén B')
# (506, 'Artículo506', 'Hogar', 447.65, 7, 'Proveedor3', '2023-10-18', 'Almacén A')
# (507, 'Producto507', 'Moda', 481.26, 70, 'Proveedor1', '2023-07-08', 'Almacén C')
# (508, 'Artículo508', 'Jardín', 387.52, 45, 'Proveedor3', '2023-04-22', 'Almacén B')
# (509, 'Objeto509', 'Electrónica', 385.09, 93, 'Proveedor1', '2023-12-25', 'Almacén A')
# (510, 'Producto510', 'Moda', 224.58, 70, 'Proveedor1', '2023-09-21', 'Almacén C')
# (511, 'Producto511', 'Electrónica', 198.99, 92, 'Proveedor3', '2023-02-05', 'Almacén A')
# (512, 'Producto512', 'Hogar', 70.38, 4, 'Proveedor1', '2023-08-26', 'Almacén B')
# (513, 'Objeto513', 'Electrónica', 37.25, 4, 'Proveedor1', '2023-12-07', 'Almacén C')
# (514, 'Producto514', 'Jardín', 104.89, 90, 'Proveedor2', '2023-07-04', 'Almacén C')
# (515, 'Producto515', 'Deportes', 473.36, 55, 'Proveedor1', '2023-05-28', 'Almacén A')
# (516, 'Objeto516', 'Electrónica', 460.01, 68, 'Proveedor2', '2023-07-10', 'Almacén C')
# (517, 'Objeto517', 'Jardín', 169.16, 56, 'Proveedor1', '2023-02-26', 'Almacén C')
# (518, 'Artículo518', 'Jardín', 486.73, 8, 'Proveedor1', '2023-08-20', 'Almacén A')
# (519, 'Producto519', 'Deportes', 301.14, 63, 'Proveedor2', '2023-04-20', 'Almacén A')
# (520, 'Producto520', 'Deportes', 142.84, 16, 'Proveedor2', '2023-03-22', 'Almacén B')
# (521, 'Producto521', 'Moda', 490.54, 10, 'Proveedor3', '2023-03-07', 'Almacén C')
# (522, 'Artículo522', 'Deportes', 213.22, 77, 'Proveedor1', '2023-06-23', 'Almacén B')
# (523, 'Artículo523', 'Moda', 318.88, 48, 'Proveedor1', '2023-09-11', 'Almacén C')
# (524, 'Objeto524', 'Deportes', 440.19, 49, 'Proveedor3', '2023-06-09', 'Almacén C')
# (525, 'Producto525', 'Moda', 314.88, 72, 'Proveedor1', '2023-04-15', 'Almacén A')
# (526, 'Artículo526', 'Deportes', 382.33, 10, 'Proveedor1', '2023-11-02', 'Almacén C')
# (527, 'Objeto527', 'Electrónica', 380.85, 29, 'Proveedor3', '2023-11-11', 'Almacén B')
# (528, 'Producto528', 'Jardín', 451.24, 63, 'Proveedor3', '2023-08-20', 'Almacén A')
# (529, 'Producto529', 'Jardín', 265.05, 71, 'Proveedor1', '2023-06-04', 'Almacén C')
# (530, 'Artículo530', 'Deportes', 420.82, 63, 'Proveedor2', '2023-05-02', 'Almacén B')
# (531, 'Objeto531', 'Moda', 219.75, 50, 'Proveedor2', '2023-11-10', 'Almacén B')
# (532, 'Producto532', 'Hogar', 492.27, 75, 'Proveedor2', '2023-05-08', 'Almacén C')
# (533, 'Producto533', 'Electrónica', 214.66, 41, 'Proveedor2', '2023-12-05', 'Almacén C')
# (534, 'Artículo534', 'Deportes', 296.38, 20, 'Proveedor3', '2023-08-26', 'Almacén C')
# (535, 'Artículo535', 'Jardín', 16.71, 51, 'Proveedor3', '2023-09-04', 'Almacén A')
# (536, 'Objeto536', 'Moda', 433.31, 58, 'Proveedor1', '2023-02-07', 'Almacén C')
# (537, 'Artículo537', 'Jardín', 355.5, 73, 'Proveedor3', '2023-05-07', 'Almacén C')
# (538, 'Objeto538', 'Deportes', 34.21, 60, 'Proveedor3', '2023-04-21', 'Almacén B')
# (539, 'Artículo539', 'Deportes', 13.45, 71, 'Proveedor3', '2023-01-01', 'Almacén A')
# (540, 'Producto540', 'Hogar', 181.59, 77, 'Proveedor2', '2023-08-26', 'Almacén B')
# (541, 'Producto541', 'Hogar', 151.07, 73, 'Proveedor1', '2023-09-18', 'Almacén A')
# (542, 'Producto542', 'Jardín', 265.36, 97, 'Proveedor3', '2023-02-11', 'Almacén A')
# (543, 'Producto543', 'Hogar', 243.91, 11, 'Proveedor3', '2023-08-19', 'Almacén C')
# (544, 'Producto544', 'Hogar', 321.81, 62, 'Proveedor2', '2023-12-24', 'Almacén B')
# (545, 'Artículo545', 'Moda', 81.1, 57, 'Proveedor2', '2023-02-11', 'Almacén C')
# (546, 'Objeto546', 'Jardín', 123.63, 28, 'Proveedor2', '2023-10-04', 'Almacén B')
# (547, 'Producto547', 'Moda', 340.23, 99, 'Proveedor2', '2023-06-28', 'Almacén B')
# (548, 'Artículo548', 'Moda', 168.61, 27, 'Proveedor3', '2023-04-12', 'Almacén A')
# (549, 'Objeto549', 'Hogar', 23.56, 97, 'Proveedor3', '2023-08-03', 'Almacén A')
# (550, 'Producto550', 'Electrónica', 131, 87, 'Proveedor2', '2023-06-04', 'Almacén B')
# (551, 'Producto551', 'Electrónica', 109.13, 82, 'Proveedor3', '2023-03-09', 'Almacén C')
# (552, 'Artículo552', 'Hogar', 139.75, 77, 'Proveedor3', '2023-12-19', 'Almacén A')
# (553, 'Producto553', 'Electrónica', 223.25, 31, 'Proveedor1', '2023-08-19', 'Almacén A')
# (554, 'Objeto554', 'Hogar', 56.86, 53, 'Proveedor1', '2023-02-04', 'Almacén A')
# (555, 'Producto555', 'Deportes', 120.48, 16, 'Proveedor3', '2023-10-10', 'Almacén C')
# (556, 'Artículo556', 'Hogar', 421.1, 60, 'Proveedor1', '2023-07-10', 'Almacén B')
# (557, 'Objeto557', 'Electrónica', 190.81, 49, 'Proveedor1', '2023-02-02', 'Almacén A')
# (558, 'Producto558', 'Moda', 497.63, 13, 'Proveedor2', '2023-09-08', 'Almacén C')
# (559, 'Artículo559', 'Jardín', 474.69, 13, 'Proveedor2', '2023-12-08', 'Almacén A')
# (560, 'Artículo560', 'Hogar', 451.53, 87, 'Proveedor2', '2023-01-18', 'Almacén C')
# (561, 'Objeto561', 'Deportes', 149.3, 73, 'Proveedor3', '2023-04-15', 'Almacén C')
# (562, 'Artículo562', 'Moda', 289.13, 100, 'Proveedor3', '2023-08-19', 'Almacén B')
# (563, 'Objeto563', 'Jardín', 320.89, 61, 'Proveedor1', '2023-07-23', 'Almacén B')
# (564, 'Objeto564', 'Electrónica', 79.55, 81, 'Proveedor3', '2023-08-10', 'Almacén A')
# (565, 'Producto565', 'Hogar', 325.75, 47, 'Proveedor3', '2023-10-23', 'Almacén C')
# (566, 'Objeto566', 'Hogar', 203.34, 29, 'Proveedor3', '2023-03-27', 'Almacén A')
# (567, 'Producto567', 'Moda', 456.53, 56, 'Proveedor3', '2023-02-08', 'Almacén C')
# (568, 'Producto568', 'Jardín', 397.17, 72, 'Proveedor1', '2023-07-15', 'Almacén B')
# (569, 'Objeto569', 'Jardín', 401.7, 36, 'Proveedor1', '2023-01-27', 'Almacén B')
# (570, 'Artículo570', 'Hogar', 478.4, 58, 'Proveedor2', '2023-11-04', 'Almacén A')
# (571, 'Producto571', 'Moda', 477.16, 65, 'Proveedor1', '2023-05-22', 'Almacén A')
# (572, 'Artículo572', 'Electrónica', 20.86, 89, 'Proveedor1', '2023-12-21', 'Almacén C')
# (573, 'Objeto573', 'Jardín', 265.73, 99, 'Proveedor1', '2023-08-03', 'Almacén C')
# (574, 'Producto574', 'Moda', 317.43, 93, 'Proveedor2', '2023-02-13', 'Almacén C')
# (575, 'Artículo575', 'Electrónica', 65.37, 86, 'Proveedor3', '2023-04-03', 'Almacén A')
# ...
# (9816, 'Objeto9816', 'Jardín', 220.65, 88, 'Proveedor1', '2023-03-06', 'Almacén B')
# (9817, 'Artículo9817', 'Hogar', 437.1, 100, 'Proveedor2', '2023-09-27', 'Almacén C')
# (9818, 'Artículo9818', 'Jardín', 437.09, 18, 'Proveedor1', '2023-11-11', 'Almacén B')
# (9819, 'Artículo9819', 'Moda', 140.02, 41, 'Proveedor1', '2023-01-20', 'Almacén A')
# (9820, 'Producto9820', 'Jardín', 417.12, 72, 'Proveedor3', '2023-02-02', 'Almacén B')
# (9821, 'Artículo9821', 'Moda', 10.71, 21, 'Proveedor3', '2023-01-03', 'Almacén A')
# (9822, 'Objeto9822', 'Deportes', 374.34, 31, 'Proveedor3', '2023-03-14', 'Almacén B')
# (9823, 'Producto9823', 'Moda', 240.5, 27, 'Proveedor2', '2023-08-24', 'Almacén A')
# (9824, 'Objeto9824', 'Electrónica', 198.45, 90, 'Proveedor2', '2023-12-06', 'Almacén C')
# (9825, 'Artículo9825', 'Electrónica', 261.36, 3, 'Proveedor3', '2023-05-10', 'Almacén A')
# (9826, 'Objeto9826', 'Moda', 152.73, 81, 'Proveedor3', '2023-06-14', 'Almacén C')
# (9827, 'Objeto9827', 'Hogar', 482.47, 66, 'Proveedor2', '2023-05-28', 'Almacén C')
# (9828, 'Artículo9828', 'Moda', 274.85, 3, 'Proveedor2', '2023-09-08', 'Almacén C')
# (9829, 'Objeto9829', 'Electrónica', 393.8, 67, 'Proveedor3', '2023-07-12', 'Almacén B')
# (9830, 'Producto9830', 'Jardín', 91.66, 67, 'Proveedor2', '2023-11-21', 'Almacén B')
# (9831, 'Objeto9831', 'Jardín', 15.52, 95, 'Proveedor1', '2023-09-10', 'Almacén A')
# (9832, 'Objeto9832', 'Deportes', 359.14, 28, 'Proveedor1', '2023-12-22', 'Almacén A')
# (9833, 'Producto9833', 'Deportes', 250.32, 49, 'Proveedor2', '2023-12-19', 'Almacén A')
# (9834, 'Producto9834', 'Jardín', 439.26, 73, 'Proveedor3', '2023-12-26', 'Almacén C')
# (9835, 'Artículo9835', 'Hogar', 122.61, 77, 'Proveedor2', '2023-02-22', 'Almacén B')
# (9836, 'Producto9836', 'Moda', 423.03, 84, 'Proveedor1', '2023-03-20', 'Almacén C')
# (9837, 'Objeto9837', 'Hogar', 365.36, 54, 'Proveedor1', '2023-05-26', 'Almacén B')
# (9838, 'Objeto9838', 'Deportes', 387.2, 72, 'Proveedor1', '2023-04-15', 'Almacén B')
# (9839, 'Objeto9839', 'Moda', 249.84, 89, 'Proveedor1', '2023-06-28', 'Almacén C')
# (9840, 'Producto9840', 'Jardín', 378.25, 58, 'Proveedor2', '2023-08-25', 'Almacén B')
# (9841, 'Objeto9841', 'Hogar', 61.52, 79, 'Proveedor1', '2023-07-05', 'Almacén B')
# (9842, 'Producto9842', 'Moda', 41.93, 18, 'Proveedor2', '2023-08-11', 'Almacén B')
# (9843, 'Producto9843', 'Deportes', 121.72, 35, 'Proveedor2', '2023-05-02', 'Almacén C')
# (9844, 'Producto9844', 'Electrónica', 405.99, 73, 'Proveedor2', '2023-06-05', 'Almacén B')
# (9845, 'Objeto9845', 'Electrónica', 171.96, 83, 'Proveedor1', '2023-08-11', 'Almacén C')
# (9846, 'Producto9846', 'Hogar', 55.78, 69, 'Proveedor1', '2023-10-27', 'Almacén B')
# (9847, 'Objeto9847', 'Moda', 346.81, 3, 'Proveedor3', '2023-11-13', 'Almacén B')
# (9848, 'Producto9848', 'Deportes', 485.57, 25, 'Proveedor1', '2023-09-24', 'Almacén B')
# (9849, 'Objeto9849', 'Deportes', 397.39, 9, 'Proveedor3', '2023-06-09', 'Almacén A')
# (9850, 'Artículo9850', 'Electrónica', 318.46, 8, 'Proveedor1', '2023-04-17', 'Almacén B')
# (9851, 'Objeto9851', 'Electrónica', 141.9, 31, 'Proveedor1', '2023-09-14', 'Almacén A')
# (9852, 'Objeto9852', 'Electrónica', 128.13, 15, 'Proveedor1', '2023-04-10', 'Almacén A')
# (9853, 'Objeto9853', 'Moda', 290.76, 68, 'Proveedor3', '2023-03-16', 'Almacén B')
# (9854, 'Producto9854', 'Deportes', 280.39, 74, 'Proveedor1', '2023-01-14', 'Almacén B')
# (9855, 'Objeto9855', 'Electrónica', 215.24, 26, 'Proveedor2', '2023-12-04', 'Almacén B')
# (9856, 'Artículo9856', 'Jardín', 274.51, 80, 'Proveedor1', '2023-04-16', 'Almacén A')
# (9857, 'Producto9857', 'Deportes', 493.46, 5, 'Proveedor1', '2023-03-08', 'Almacén B')
# (9858, 'Objeto9858', 'Hogar', 26.74, 78, 'Proveedor2', '2023-12-13', 'Almacén A')
# (9859, 'Artículo9859', 'Hogar', 45.26, 23, 'Proveedor1', '2023-11-03', 'Almacén A')
# (9860, 'Objeto9860', 'Deportes', 494.18, 22, 'Proveedor3', '2023-08-07', 'Almacén B')
# (9861, 'Objeto9861', 'Electrónica', 310.23, 60, 'Proveedor2', '2023-04-14', 'Almacén A')
# (9862, 'Objeto9862', 'Jardín', 220.17, 13, 'Proveedor1', '2023-08-04', 'Almacén C')
# (9863, 'Artículo9863', 'Moda', 223.87, 7, 'Proveedor3', '2023-05-06', 'Almacén A')
# (9864, 'Artículo9864', 'Deportes', 290.73, 47, 'Proveedor2', '2023-05-02', 'Almacén A')
# (9865, 'Objeto9865', 'Jardín', 271.29, 14, 'Proveedor2', '2023-09-02', 'Almacén C')
# (9866, 'Artículo9866', 'Moda', 310.12, 23, 'Proveedor1', '2023-03-19', 'Almacén C')
# (9867, 'Artículo9867', 'Deportes', 127, 57, 'Proveedor1', '2023-01-05', 'Almacén A')
# (9868, 'Objeto9868', 'Electrónica', 442.37, 85, 'Proveedor3', '2023-01-25', 'Almacén B')
# (9869, 'Artículo9869', 'Electrónica', 134.27, 49, 'Proveedor3', '2023-03-19', 'Almacén B')
# (9870, 'Objeto9870', 'Jardín', 227.97, 38, 'Proveedor2', '2023-04-09', 'Almacén C')
# (9871, 'Artículo9871', 'Moda', 53.06, 2, 'Proveedor3', '2023-05-07', 'Almacén C')
# (9872, 'Artículo9872', 'Hogar', 279.39, 95, 'Proveedor3', '2023-10-28', 'Almacén C')
# (9873, 'Artículo9873', 'Hogar', 23.66, 35, 'Proveedor3', '2023-06-24', 'Almacén C')
# (9874, 'Producto9874', 'Moda', 261.58, 62, 'Proveedor3', '2023-06-14', 'Almacén A')
# (9875, 'Objeto9875', 'Hogar', 496.73, 64, 'Proveedor3', '2023-05-16', 'Almacén C')
# (9876, 'Artículo9876', 'Deportes', 138.13, 85, 'Proveedor2', '2023-06-26', 'Almacén A')
# (9877, 'Artículo9877', 'Deportes', 176.99, 46, 'Proveedor3', '2023-10-08', 'Almacén C')
# (9878, 'Artículo9878', 'Hogar', 447.13, 31, 'Proveedor1', '2023-02-13', 'Almacén C')
# (9879, 'Producto9879', 'Electrónica', 361.09, 41, 'Proveedor2', '2023-01-23', 'Almacén A')
# (9880, 'Artículo9880', 'Hogar', 298.25, 87, 'Proveedor1', '2023-01-02', 'Almacén A')
# (9881, 'Artículo9881', 'Deportes', 301.3, 83, 'Proveedor1', '2023-09-04', 'Almacén A')
# (9882, 'Artículo9882', 'Jardín', 466.09, 34, 'Proveedor1', '2023-08-19', 'Almacén B')
# (9883, 'Artículo9883', 'Deportes', 249.35, 82, 'Proveedor2', '2023-08-12', 'Almacén C')
# (9884, 'Producto9884', 'Hogar', 412.2, 87, 'Proveedor1', '2023-01-22', 'Almacén A')
# (9885, 'Artículo9885', 'Electrónica', 494.51, 21, 'Proveedor2', '2023-04-21', 'Almacén C')
# (9886, 'Artículo9886', 'Hogar', 139.76, 33, 'Proveedor1', '2023-06-03', 'Almacén C')
# (9887, 'Artículo9887', 'Electrónica', 323.76, 23, 'Proveedor1', '2023-08-06', 'Almacén C')
# (9888, 'Producto9888', 'Moda', 239.34, 72, 'Proveedor1', '2023-02-05', 'Almacén B')
# (9889, 'Objeto9889', 'Moda', 195.02, 15, 'Proveedor2', '2023-03-16', 'Almacén B')
# (9890, 'Artículo9890', 'Hogar', 388.03, 76, 'Proveedor2', '2023-06-21', 'Almacén B')
# (9891, 'Objeto9891', 'Jardín', 485.02, 9, 'Proveedor3', '2023-07-09', 'Almacén C')
# (9892, 'Artículo9892', 'Deportes', 58.34, 37, 'Proveedor1', '2023-09-26', 'Almacén C')
# (9893, 'Artículo9893', 'Jardín', 172.99, 7, 'Proveedor1', '2023-10-15', 'Almacén A')
# (9894, 'Objeto9894', 'Electrónica', 396.13, 83, 'Proveedor2', '2023-06-24', 'Almacén A')
# (9895, 'Objeto9895', 'Electrónica', 392.36, 38, 'Proveedor3', '2023-11-03', 'Almacén A')
# (9896, 'Artículo9896', 'Moda', 253.73, 6, 'Proveedor1', '2023-09-01', 'Almacén C')
# (9897, 'Objeto9897', 'Hogar', 285.04, 64, 'Proveedor2', '2023-03-22', 'Almacén A')
# (9898, 'Objeto9898', 'Deportes', 265.77, 21, 'Proveedor3', '2023-09-11', 'Almacén A')
# (9899, 'Objeto9899', 'Deportes', 155.3, 15, 'Proveedor3', '2023-03-14', 'Almacén A')
# (9900, 'Objeto9900', 'Electrónica', 116.26, 83, 'Proveedor2', '2023-01-28', 'Almacén A')
# (9901, 'Artículo9901', 'Deportes', 147.16, 73, 'Proveedor2', '2023-03-04', 'Almacén A')
# (9902, 'Artículo9902', 'Deportes', 29.97, 21, 'Proveedor3', '2023-02-13', 'Almacén A')
# (9903, 'Producto9903', 'Jardín', 358.94, 44, 'Proveedor3', '2023-06-22', 'Almacén C')
# (9904, 'Producto9904', 'Moda', 387.55, 2, 'Proveedor2', '2023-04-15', 'Almacén A')
# (9905, 'Artículo9905', 'Hogar', 340.59, 64, 'Proveedor1', '2023-07-18', 'Almacén A')
# (9906, 'Artículo9906', 'Electrónica', 358.91, 78, 'Proveedor3', '2023-11-22', 'Almacén B')
# (9907, 'Producto9907', 'Moda', 171.27, 61, 'Proveedor3', '2023-10-01', 'Almacén C')
# (9908, 'Artículo9908', 'Moda', 149.36, 21, 'Proveedor3', '2023-11-27', 'Almacén B')
# (9909, 'Objeto9909', 'Electrónica', 207.99, 89, 'Proveedor3', '2023-09-14', 'Almacén A')
# (9910, 'Producto9910', 'Electrónica', 151.21, 56, 'Proveedor1', '2023-03-08', 'Almacén A')
# (9911, 'Objeto9911', 'Electrónica', 298.39, 19, 'Proveedor2', '2023-02-19', 'Almacén C')
# (9912, 'Objeto9912', 'Deportes', 89.79, 42, 'Proveedor2', '2023-05-21', 'Almacén A')
# (9913, 'Producto9913', 'Deportes', 166.06, 50, 'Proveedor1', '2023-08-27', 'Almacén B')
# (9914, 'Artículo9914', 'Deportes', 260.64, 54, 'Proveedor2', '2023-02-23', 'Almacén C')
# (9915, 'Artículo9915', 'Electrónica', 14.37, 62, 'Proveedor3', '2023-02-28', 'Almacén A')
# (9916, 'Producto9916', 'Jardín', 184.99, 88, 'Proveedor2', '2023-09-27', 'Almacén A')
# (9917, 'Objeto9917', 'Electrónica', 499.82, 17, 'Proveedor3', '2023-07-07', 'Almacén B')
# (9918, 'Objeto9918', 'Moda', 484.61, 8, 'Proveedor3', '2023-11-23', 'Almacén C')
# (9919, 'Artículo9919', 'Moda', 357.27, 66, 'Proveedor3', '2023-07-01', 'Almacén A')
# (9920, 'Objeto9920', 'Deportes', 135.04, 34, 'Proveedor2', '2023-04-04', 'Almacén C')
# (9921, 'Artículo9921', 'Electrónica', 96.65, 64, 'Proveedor3', '2023-11-12', 'Almacén B')
# (9922, 'Objeto9922', 'Deportes', 158.71, 16, 'Proveedor1', '2023-06-21', 'Almacén B')
# (9923, 'Objeto9923', 'Electrónica', 53.82, 34, 'Proveedor2', '2023-03-20', 'Almacén A')
# (9924, 'Objeto9924', 'Deportes', 162.18, 63, 'Proveedor3', '2023-05-09', 'Almacén B')
# (9925, 'Artículo9925', 'Deportes', 11.36, 48, 'Proveedor2', '2023-11-01', 'Almacén B')
# (9926, 'Producto9926', 'Electrónica', 27.83, 41, 'Proveedor2', '2023-02-25', 'Almacén B')
# (9927, 'Artículo9927', 'Jardín', 411.67, 75, 'Proveedor1', '2023-11-04', 'Almacén A')
# (9928, 'Objeto9928', 'Hogar', 436.58, 50, 'Proveedor1', '2023-09-24', 'Almacén A')
# (9929, 'Producto9929', 'Electrónica', 265.4, 73, 'Proveedor3', '2023-06-15', 'Almacén B')
# (9930, 'Producto9930', 'Electrónica', 263.37, 5, 'Proveedor3', '2023-07-06', 'Almacén A')
# (9931, 'Producto9931', 'Electrónica', 497.91, 32, 'Proveedor2', '2023-03-06', 'Almacén B')
# (9932, 'Objeto9932', 'Moda', 467.27, 63, 'Proveedor1', '2023-05-03', 'Almacén B')
# (9933, 'Producto9933', 'Hogar', 118.98, 40, 'Proveedor3', '2023-07-28', 'Almacén C')
# (9934, 'Artículo9934', 'Electrónica', 141.67, 92, 'Proveedor3', '2023-07-07', 'Almacén A')
# (9935, 'Producto9935', 'Deportes', 218.95, 65, 'Proveedor2', '2023-11-18', 'Almacén B')
# (9936, 'Artículo9936', 'Jardín', 215.09, 9, 'Proveedor3', '2023-10-14', 'Almacén B')
# (9937, 'Artículo9937', 'Moda', 120.95, 46, 'Proveedor2', '2023-09-08', 'Almacén A')
# (9938, 'Artículo9938', 'Hogar', 136.77, 50, 'Proveedor2', '2023-02-23', 'Almacén B')
# (9939, 'Artículo9939', 'Electrónica', 96.84, 98, 'Proveedor2', '2023-08-27', 'Almacén A')
# (9940, 'Artículo9940', 'Deportes', 98.47, 28, 'Proveedor2', '2023-02-21', 'Almacén A')
# (9941, 'Artículo9941', 'Deportes', 248.99, 27, 'Proveedor2', '2023-09-07', 'Almacén C')
# (9942, 'Producto9942', 'Hogar', 228.92, 100, 'Proveedor3', '2023-05-11', 'Almacén C')
# (9943, 'Producto9943', 'Moda', 312.69, 52, 'Proveedor2', '2023-11-21', 'Almacén C')
# (9944, 'Producto9944', 'Moda', 158.8, 74, 'Proveedor1', '2023-02-26', 'Almacén A')
# (9945, 'Objeto9945', 'Hogar', 208.51, 42, 'Proveedor3', '2023-04-04', 'Almacén B')
# (9946, 'Artículo9946', 'Deportes', 152.79, 60, 'Proveedor3', '2023-01-19', 'Almacén A')
# (9947, 'Producto9947', 'Deportes', 492.46, 59, 'Proveedor3', '2023-04-14', 'Almacén B')
# (9948, 'Artículo9948', 'Deportes', 173.44, 72, 'Proveedor2', '2023-10-08', 'Almacén C')
# (9949, 'Producto9949', 'Deportes', 84.19, 47, 'Proveedor2', '2023-04-16', 'Almacén B')
# (9950, 'Artículo9950', 'Hogar', 207.9, 72, 'Proveedor2', '2023-07-02', 'Almacén B')
# (9951, 'Producto9951', 'Hogar', 170.06, 69, 'Proveedor2', '2023-08-16', 'Almacén B')
# (9952, 'Artículo9952', 'Jardín', 445.93, 58, 'Proveedor2', '2023-05-02', 'Almacén A')
# (9953, 'Objeto9953', 'Moda', 420.41, 60, 'Proveedor2', '2023-07-07', 'Almacén B')
# (9954, 'Artículo9954', 'Electrónica', 458.06, 35, 'Proveedor3', '2023-09-26', 'Almacén B')
# (9955, 'Producto9955', 'Jardín', 490.86, 20, 'Proveedor3', '2023-03-14', 'Almacén C')
# (9956, 'Artículo9956', 'Hogar', 182.01, 76, 'Proveedor2', '2023-06-11', 'Almacén B')
# (9957, 'Objeto9957', 'Jardín', 241.59, 57, 'Proveedor3', '2023-08-03', 'Almacén C')
# (9958, 'Producto9958', 'Moda', 365.06, 91, 'Proveedor1', '2023-08-09', 'Almacén A')
# (9959, 'Objeto9959', 'Moda', 169.4, 73, 'Proveedor1', '2023-02-13', 'Almacén A')
# (9960, 'Producto9960', 'Moda', 92.1, 45, 'Proveedor2', '2023-12-24', 'Almacén B')
# (9961, 'Objeto9961', 'Deportes', 350.27, 71, 'Proveedor3', '2023-05-09', 'Almacén A')
# (9962, 'Objeto9962', 'Deportes', 398.51, 80, 'Proveedor1', '2023-11-08', 'Almacén B')
# (9963, 'Artículo9963', 'Jardín', 81.38, 7, 'Proveedor2', '2023-05-21', 'Almacén C')
# (9964, 'Objeto9964', 'Electrónica', 232.93, 49, 'Proveedor1', '2023-01-04', 'Almacén B')
# (9965, 'Artículo9965', 'Jardín', 56.93, 21, 'Proveedor2', '2023-01-24', 'Almacén B')
# (9966, 'Producto9966', 'Hogar', 192.9, 33, 'Proveedor1', '2023-08-08', 'Almacén C')
# (9967, 'Producto9967', 'Electrónica', 441.27, 86, 'Proveedor3', '2023-10-05', 'Almacén A')
# (9968, 'Producto9968', 'Moda', 367.04, 22, 'Proveedor2', '2023-06-02', 'Almacén B')
# (9969, 'Objeto9969', 'Hogar', 445.78, 19, 'Proveedor3', '2023-06-20', 'Almacén C')
# (9970, 'Artículo9970', 'Moda', 395.03, 23, 'Proveedor1', '2023-09-24', 'Almacén C')
# (9971, 'Producto9971', 'Jardín', 328.21, 77, 'Proveedor3', '2023-04-24', 'Almacén C')
# (9972, 'Objeto9972', 'Moda', 469.86, 94, 'Proveedor1', '2023-06-15', 'Almacén C')
# (9973, 'Producto9973', 'Electrónica', 282.02, 28, 'Proveedor3', '2023-12-22', 'Almacén B')
# (9974, 'Objeto9974', 'Deportes', 80.74, 19, 'Proveedor3', '2023-09-08', 'Almacén B')
# (9975, 'Artículo9975', 'Jardín', 195.88, 26, 'Proveedor2', '2023-05-03', 'Almacén A')
# (9976, 'Artículo9976', 'Deportes', 62.2, 56, 'Proveedor2', '2023-05-23', 'Almacén A')
# (9977, 'Producto9977', 'Hogar', 241.55, 94, 'Proveedor2', '2023-05-04', 'Almacén B')
# (9978, 'Artículo9978', 'Hogar', 337.69, 70, 'Proveedor2', '2023-06-05', 'Almacén A')
# (9979, 'Producto9979', 'Jardín', 107.6, 45, 'Proveedor2', '2023-10-18', 'Almacén C')
# (9980, 'Artículo9980', 'Deportes', 448.37, 35, 'Proveedor1', '2023-10-23', 'Almacén A')
# (9981, 'Artículo9981', 'Electrónica', 402.47, 88, 'Proveedor1', '2023-10-14', 'Almacén B')
# (9982, 'Producto9982', 'Electrónica', 165.42, 89, 'Proveedor2', '2023-12-24', 'Almacén C')
# (9983, 'Artículo9983', 'Electrónica', 424.72, 74, 'Proveedor2', '2023-12-22', 'Almacén A')
# (9984, 'Producto9984', 'Jardín', 158.71, 21, 'Proveedor1', '2023-09-11', 'Almacén B')
# (9985, 'Producto9985', 'Hogar', 206.41, 40, 'Proveedor2', '2023-11-04', 'Almacén A')
# (9986, 'Artículo9986', 'Jardín', 312.55, 85, 'Proveedor1', '2023-10-09', 'Almacén A')
# (9987, 'Artículo9987', 'Electrónica', 343.81, 51, 'Proveedor1', '2023-04-12', 'Almacén A')
# (9988, 'Producto9988', 'Deportes', 377.79, 34, 'Proveedor1', '2023-04-06', 'Almacén A')
# (9989, 'Objeto9989', 'Electrónica', 185.54, 86, 'Proveedor3', '2023-01-05', 'Almacén A')
# (9990, 'Artículo9990', 'Deportes', 498.28, 85, 'Proveedor1', '2023-06-19', 'Almacén A')
# (9991, 'Objeto9991', 'Jardín', 185.69, 54, 'Proveedor1', '2023-02-14', 'Almacén A')
# (9992, 'Artículo9992', 'Jardín', 195.04, 8, 'Proveedor3', '2023-03-26', 'Almacén B')
# (9993, 'Artículo9993', 'Moda', 151.01, 37, 'Proveedor3', '2023-07-03', 'Almacén A')
# (9994, 'Artículo9994', 'Hogar', 55.58, 34, 'Proveedor3', '2023-02-10', 'Almacén B')
# (9995, 'Objeto9995', 'Deportes', 489.44, 90, 'Proveedor1', '2023-03-18', 'Almacén C')
# (9996, 'Artículo9996', 'Jardín', 80.15, 20, 'Proveedor3', '2023-02-01', 'Almacén A')
# (9997, 'Objeto9997', 'Jardín', 81.46, 74, 'Proveedor1', '2023-12-28', 'Almacén A')
# (9998, 'Objeto9998', 'Deportes', 458.56, 78, 'Proveedor2', '2023-07-21', 'Almacén B')
# (9999, 'Artículo9999', 'Jardín', 283.84, 86, 'Proveedor1', '2023-08-25', 'Almacén C')
# (10000, 'Artículo10000', 'Hogar', 123.59, 77, 'Proveedor2', '2023-03-02', 'Almacén A')

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#         id        nombre categoria  precio  cantidad   proveedor  \
# 0        5       Objeto5    Jardín  456.25        34  Proveedor1
# 1       24    Producto24     Hogar  456.64        61  Proveedor1
# 2       54    Artículo54    Jardín  471.35        18  Proveedor1
# 3       56      Objeto56    Jardín  485.91        18  Proveedor1
# 4      132   Producto132    Jardín  477.46        72  Proveedor3
# ...    ...           ...       ...     ...       ...         ...
# 1042  9955  Producto9955    Jardín  490.86        20  Proveedor3
# 1043  9972    Objeto9972      Moda  469.86        94  Proveedor1
# 1044  9990  Artículo9990  Deportes  498.28        85  Proveedor1
# 1045  9995    Objeto9995  Deportes  489.44        90  Proveedor1
# 1046  9998    Objeto9998  Deportes  458.56        78  Proveedor2
#
#      fecha_ingreso  ubicacion
# 0       2023-05-20  Almacén C
# 1       2023-07-12  Almacén B
# 2       2023-03-11  Almacén B
# 3       2023-08-07  Almacén B
# 4       2023-01-21  Almacén A
# ...            ...        ...
# 1042    2023-03-14  Almacén C
# 1043    2023-06-15  Almacén C
# 1044    2023-06-19  Almacén A
# 1045    2023-03-18  Almacén C
# 1046    2023-07-21  Almacén B
#
# [1047 rows x 8 columns]

# %%
df_productos.head()
# Out:
#     id       nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0    5      Objeto5    Jardín  456.25        34  Proveedor1    2023-05-20
# 1   24   Producto24     Hogar  456.64        61  Proveedor1    2023-07-12
# 2   54   Artículo54    Jardín  471.35        18  Proveedor1    2023-03-11
# 3   56     Objeto56    Jardín  485.91        18  Proveedor1    2023-08-07
# 4  132  Producto132    Jardín  477.46        72  Proveedor3    2023-01-21
#
#    ubicacion
# 0  Almacén C
# 1  Almacén B
# 2  Almacén B
# 3  Almacén B
# 4  Almacén A

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#        id        nombre    categoria  precio  cantidad   proveedor  \
# 0       5       Objeto5       Jardín  456.25        34  Proveedor1
# 1      24    Producto24        Hogar  456.64        61  Proveedor1
# 2     132   Producto132       Jardín  477.46        72  Proveedor3
# 3     147   Producto147         Moda  480.96        91  Proveedor2
# 4     174     Objeto174         Moda  482.71        88  Proveedor3
# ..    ...           ...          ...     ...       ...         ...
# 776  9954  Artículo9954  Electrónica  458.06        35  Proveedor3
# 777  9972    Objeto9972         Moda  469.86        94  Proveedor1
# 778  9990  Artículo9990     Deportes  498.28        85  Proveedor1
# 779  9995    Objeto9995     Deportes  489.44        90  Proveedor1
# 780  9998    Objeto9998     Deportes  458.56        78  Proveedor2
#
#     fecha_ingreso  ubicacion
# 0      2023-05-20  Almacén C
# 1      2023-07-12  Almacén B
# 2      2023-01-21  Almacén A
# 3      2023-03-12  Almacén C
# 4      2023-10-23  Almacén A
# ..            ...        ...
# 776    2023-09-26  Almacén B
# 777    2023-06-15  Almacén C
# 778    2023-06-19  Almacén A
# 779    2023-03-18  Almacén C
# 780    2023-07-21  Almacén B
#
# [781 rows x 8 columns]

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-06 11:58:17.218518  Almacén B
# 1 2025-03-11 11:58:17.218572  Almacén C
# 2 2024-12-17 11:58:17.218590  Almacén B
# 3 2025-08-14 11:58:17.218604  Almacén A
# 4 2024-11-30 11:58:17.218616  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-06 11:58:17.219  Almacén B
# 1 2025-03-11 11:58:17.219  Almacén C
# 2 2024-12-17 11:58:17.219  Almacén B
# 3 2025-08-14 11:58:17.219  Almacén A
# 4 2024-11-30 11:58:17.219  Almacén A

# %%
import sqlite3

# Conexión con la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Inserción de datos en la base de datos
for index, row in df.iterrows():
    c.execute("""
    INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
    VALUES (?, ?, ?, ?, ?, ?, ?)
    """, (
        row['Nombre'],
        row['Categoría'],
        row['Precio'],
        row['Cantidad'],
        row['Proveedor'],
        row['Fecha de Ingreso'],
        row['Ubicación']
        ))

conn.commit()

conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipython-input-2193443146.py in <cell line: 0>()
#       7 # Inserción de datos en la base de datos
#       8 for index, row in df.iterrows():
# ----> 9     c.execute("""
#      10     INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#      11     VALUES (?, ?, ?, ?, ?, ?, ?)
#
# ProgrammingError: Error binding parameter 6: type 'Timestamp' is not supported
